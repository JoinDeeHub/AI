# %% [markdown]
# #gridsearchCV_SVR

# %%
import pandas as pd

# %%
#load the dataset
dataset = pd.read_csv('insurance_pre.csv')

#dummy the categorical variables
dataset = pd.get_dummies(dataset, drop_first=True)
# Display the first few rows of the dataset
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
# Define the features and target variable
independent = dataset.drop('charges', axis=1)  
#print(independent)
dependent = dataset['charges']

# %%
# Import necessary libraries for model training and evaluation
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
# Initialize the SVR with GridSearchCV
# Create a GridSearchCV object with SVR
grid_search = GridSearchCV(
    estimator=SVR(),
    param_grid={
        'C': [0.1],
        'gamma': ['auto', 'scale'],
        'kernel': ['linear', 'poly', 'rbf', 'sigmoid']
    },
    refit=True,
    verbose=3,
    n_jobs=-1
)

# Fit the model using GridSearchCV
grid_search.fit(independent, dependent)

# R2score value for best parameters
print(f"GridSearchCV Results R2score value for best parameters: {grid_search.best_params_}")
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 2/5] END .C=0.1, gamma=auto, kernel=linear;, score=-0.103 total time=   0.1s
# [CV 5/5] END .C=0.1, gamma=auto, kernel=linear;, score=-0.216 total time=   0.1s
# [CV 1/5] END .C=0.1, gamma=auto, kernel=linear;, score=-0.157 total time=   0.2s
# [CV 3/5] END .C=0.1, gamma=auto, kernel=linear;, score=-0.118 total time=   0.1s
# [CV 4/5] END .C=0.1, gamma=auto, kernel=linear;, score=-0.140 total time=   0.1s
# [CV 1/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.859 total time= 1.6min
# [CV 4/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.796 total time= 1.6min
# [CV 1/5] END ....C=0.1, gamma=auto, kernel=rbf;, score=-0.115 total time=   0.1s
# [CV 2/5] END ....C=0.1, gamma=auto, kernel=rbf;, score=-0.114 total time=   0.1s
# [CV 3/5] END ....C=0.1, gamma=auto, kernel=rbf;, score=-0.082 total time=   0.1s
# [CV 4/5] END ....C=0.1, gamma=auto, kernel=rbf;, score=-0.106 total time=   0.1s
# [CV 5/5] END ....C=0.1, gamma=auto, kernel=rbf;, score=-0.107 total time=   0.1s
# [CV 1/5] END C=0.1, gamma=auto, kernel=sigmoid;, score=-0.115 total time=   0.1s
# [CV 2/5] END C=0.1, gamma=auto, kernel=sigmoid;, score=-0.114 total time=   0.1s
# [CV 3/5] END C=0.1, gamma=auto, kernel=sigmoid;, score=-0.082 total time=   0.1s
# [CV 4/5] END C=0.1, gamma=auto, kernel=sigmoid;, score=-0.106 total time=   0.1s
# [CV 5/5] END C=0.1, gamma=auto, kernel=sigmoid;, score=-0.107 total time=   0.1s
# [CV 1/5] END C=0.1, gamma=scale, kernel=linear;, score=-0.157 total time=   0.1s
# [CV 2/5] END C=0.1, gamma=scale, kernel=linear;, score=-0.103 total time=   0.1s
# [CV 3/5] END C=0.1, gamma=scale, kernel=linear;, score=-0.118 total time=   0.2s
# [CV 4/5] END C=0.1, gamma=scale, kernel=linear;, score=-0.140 total time=   0.1s
# [CV 5/5] END C=0.1, gamma=scale, kernel=linear;, score=-0.216 total time=   0.1s
# [CV 1/5] END ..C=0.1, gamma=scale, kernel=poly;, score=-0.113 total time=   0.2s
# [CV 2/5] END ..C=0.1, gamma=scale, kernel=poly;, score=-0.105 total time=   0.2s
# [CV 3/5] END ..C=0.1, gamma=scale, kernel=poly;, score=-0.078 total time=   0.1s
# [CV 4/5] END ..C=0.1, gamma=scale, kernel=poly;, score=-0.105 total time=   0.1s
# [CV 5/5] END ..C=0.1, gamma=scale, kernel=poly;, score=-0.108 total time=   0.2s
# [CV 1/5] END ...C=0.1, gamma=scale, kernel=rbf;, score=-0.115 total time=   0.2s
# [CV 2/5] END ...C=0.1, gamma=scale, kernel=rbf;, score=-0.113 total time=   0.3s
# [CV 3/5] END ...C=0.1, gamma=scale, kernel=rbf;, score=-0.081 total time=   0.3s
# [CV 4/5] END ...C=0.1, gamma=scale, kernel=rbf;, score=-0.106 total time=   0.1s
# [CV 5/5] END ...C=0.1, gamma=scale, kernel=rbf;, score=-0.107 total time=   0.2s
# [CV 1/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=-0.115 total time=   0.2s
# [CV 2/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=-0.114 total time=   0.2s
# [CV 3/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=-0.082 total time=   0.2s
# [CV 4/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=-0.106 total time=   0.2s
# [CV 5/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=-0.107 total time=   0.2s
# [CV 2/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.778 total time= 1.7min
# [CV 3/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.867 total time= 2.1min
# [CV 5/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.822 total time=  41.2s
# GridSearchCV Results R2score value for best parameters: {'C': 0.1, 'gamma': 'auto', 'kernel': 'poly'}

# %%
# Get the results from GridSearchCV
Results = grid_search.cv_results_
# Convert the results to a DataFrame for better readability
Results_df = pd.DataFrame.from_dict(Results)
Results_df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.091241      0.033192         0.016572        0.007839      0.1
# 1      90.856578     27.278271         0.013331        0.006116      0.1
# 2       0.105478      0.001645         0.025627        0.000734      0.1
# 3       0.074538      0.009070         0.013069        0.000115      0.1
# 4       0.107137      0.023789         0.015640        0.003725      0.1
# 5       0.139305      0.031417         0.026244        0.008867      0.1
# 6       0.183313      0.064911         0.045442        0.018089      0.1
# 7       0.155751      0.017542         0.034101        0.010566      0.1
#
#   param_gamma param_kernel                                             params  \
# 0        auto       linear    {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}
# 1        auto         poly      {'C': 0.1, 'gamma': 'auto', 'kernel': 'poly'}
# 2        auto          rbf       {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}
# 3        auto      sigmoid   {'C': 0.1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 4       scale       linear   {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 5       scale         poly     {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}
# 6       scale          rbf      {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# 7       scale      sigmoid  {'C': 0.1, 'gamma': 'scale', 'kernel': 'sigmoid'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0          -0.156586          -0.102518          -0.117799          -0.140213
# 1           0.858798           0.777670           0.867061           0.795668
# 2          -0.115312          -0.113526          -0.081580          -0.106043
# 3          -0.115328          -0.113567          -0.081608          -0.106067
# 4          -0.156586          -0.102518          -0.117799          -0.140213
# 5          -0.112857          -0.105099          -0.077609          -0.104969
# 6          -0.115326          -0.113152          -0.081428          -0.105862
# 7          -0.115314          -0.113654          -0.081616          -0.106034
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0          -0.216269        -0.146677        0.039413                7
# 1           0.821677         0.824175        0.034697                1
# 2          -0.107188        -0.104730        0.012108                4
# 3          -0.107195        -0.104753        0.012107                5
# 4          -0.216269        -0.146677        0.039413                7
# 5          -0.108333        -0.101773        0.012418                2
# 6          -0.107303        -0.104614        0.012116                3
# 7          -0.107251        -0.104774        0.012116                6

# %%
age_input = int(input("Enter the age: "))
bmi_input = float(input("Enter the BMI: "))
children_input = int(input("Enter the number of children: "))
sex_male_input = int(input("Enter 0 if you are male, 1 otherwise: "))
smoker_input = int(input("Enter 0 if you are a smoker, 1 otherwise: "))

# %%
# Create a DataFrame for the input data
input_data = pd.DataFrame({
    'age': [age_input],
    'bmi': [bmi_input],
    'children': [children_input],
    'sex_male': [sex_male_input],
    'smoker_yes': [smoker_input]
})

# %%
# Make predictions using the best model
predictions = grid_search.predict(input_data)
print(f"Predicted insurance charges: {predictions}")
# Out:
# Predicted insurance charges: [3458.07029897]
