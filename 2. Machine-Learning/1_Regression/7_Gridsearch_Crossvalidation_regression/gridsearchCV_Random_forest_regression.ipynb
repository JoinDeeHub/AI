# %% [markdown]
# #gridsearchCV_Random_forest_regression

# %%
import pandas as pd

# %%
#load the dataset
dataset = pd.read_csv('insurance_pre.csv')

#dummy the categorical variables
dataset = pd.get_dummies(dataset, drop_first=True)
# Display the first few rows of the dataset
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
# Define the features and target variable
independent = dataset.drop('charges', axis=1)  
#print(independent)
dependent = dataset['charges']

# %%
# Import necessary libraries for model training and evaluation
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
# Initialize the RandomForestRegressor with GridSearchCV
# Create a GridSearchCV object with RandomForestRegressor
GridSearchCV = GridSearchCV(
    estimator=RandomForestRegressor(),
    param_grid={
        'n_estimators': [10, 100],
        'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
        'max_features': ['sqrt', 'log2']
    },
    refit=True,
    verbose=3,
    n_jobs=-1
)

# Fit the model using GridSearchCV
GridSearchCV.fit(independent, dependent)


# R2score value for best parameters
print(f"GridSearchCV Results R2score value for best parameters: {GridSearchCV.best_params_}")
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.843 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.836 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.860 total time=   0.4s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.843 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.780 total time=   0.3s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.829 total time=   0.3s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.862 total time=   0.4s
# [CV 1/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.822 total time=   0.1s
# [CV 2/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.772 total time=   0.1s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.840 total time=   0.4s
# [CV 3/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.862 total time=   0.1s
# [CV 4/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.818 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.818 total time=   0.1s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.819 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.858 total time=   0.4s
# [CV 3/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.861 total time=   0.4s
# [CV 2/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.766 total time=   0.1s
# [CV 4/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.829 total time=   0.4s
# [CV 5/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.840 total time=   0.3s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.849 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.825 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.826 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.762 total time=   0.2s
# [CV 2/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.781 total time=   1.1s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.811 total time=   0.2s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.858 total time=   1.0s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.833 total time=   1.6s
# [CV 1/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.851 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.779 total time=   1.8s
# [CV 2/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.763 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.829 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.855 total time=   1.9s
# [CV 4/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.814 total time=   0.1s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.842 total time=   1.0s
# [CV 5/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.830 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.858 total time=   1.0s
# [CV 1/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.858 total time=   1.2s
# [CV 2/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.782 total time=   1.2s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=10;, score=0.832 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=10;, score=0.749 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=10;, score=0.847 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=10;, score=0.810 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=10;, score=0.828 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.827 total time=   1.3s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=100;, score=0.857 total time=   0.3s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=100;, score=0.784 total time=   0.4s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=100;, score=0.859 total time=   0.4s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, n_estimators=10;, score=0.847 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, n_estimators=10;, score=0.763 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, n_estimators=10;, score=0.833 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, n_estimators=10;, score=0.812 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=100;, score=0.831 total time=   0.3s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, n_estimators=10;, score=0.797 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=100;, score=0.844 total time=   0.4s
# [CV 5/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.845 total time=   1.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, n_estimators=100;, score=0.857 total time=   0.3s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, n_estimators=100;, score=0.826 total time=   0.3s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, n_estimators=100;, score=0.782 total time=   0.5s[CV 1/5] END criterion=poisson, max_features=sqrt, n_estimators=10;, score=0.844 total time=   0.0s
#
# [CV 2/5] END criterion=poisson, max_features=sqrt, n_estimators=10;, score=0.756 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=sqrt, n_estimators=10;, score=0.802 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=sqrt, n_estimators=10;, score=0.843 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_features=sqrt, n_estimators=10;, score=0.831 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, n_estimators=100;, score=0.858 total time=   0.6s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, n_estimators=100;, score=0.839 total time=   0.3s
# [CV 2/5] END criterion=poisson, max_features=sqrt, n_estimators=100;, score=0.778 total time=   0.4s
# [CV 4/5] END criterion=poisson, max_features=sqrt, n_estimators=100;, score=0.829 total time=   0.4s
# [CV 1/5] END criterion=poisson, max_features=sqrt, n_estimators=100;, score=0.858 total time=   0.5s
# [CV 3/5] END criterion=poisson, max_features=sqrt, n_estimators=100;, score=0.858 total time=   0.4s
# [CV 1/5] END criterion=poisson, max_features=log2, n_estimators=10;, score=0.834 total time=   0.1s
# [CV 3/5] END criterion=poisson, max_features=log2, n_estimators=10;, score=0.831 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=log2, n_estimators=10;, score=0.762 total time=   0.1s
# [CV 4/5] END criterion=poisson, max_features=log2, n_estimators=10;, score=0.797 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_features=log2, n_estimators=10;, score=0.824 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_features=sqrt, n_estimators=100;, score=0.839 total time=   0.4s
# [CV 2/5] END criterion=poisson, max_features=log2, n_estimators=100;, score=0.779 total time=   0.4s
# [CV 1/5] END criterion=poisson, max_features=log2, n_estimators=100;, score=0.860 total time=   0.4s
# [CV 3/5] END criterion=poisson, max_features=log2, n_estimators=100;, score=0.860 total time=   0.4s
# [CV 4/5] END criterion=poisson, max_features=log2, n_estimators=100;, score=0.828 total time=   0.3s
# [CV 5/5] END criterion=poisson, max_features=log2, n_estimators=100;, score=0.835 total time=   0.3s
# GridSearchCV Results R2score value for best parameters: {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
# Get the results from GridSearchCV
Results = GridSearchCV.cv_results_
# Convert the results to a DataFrame for better readability
Results_df = pd.DataFrame.from_dict(Results)
Results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.051597      0.026044         0.006440        0.003347
# 1        0.346760      0.029675         0.026790        0.013776
# 2        0.087937      0.027081         0.016282        0.010167
# 3        0.508202      0.276704         0.022256        0.004179
# 4        0.148045      0.047312         0.008216        0.004974
# 5        1.462193      0.389246         0.021225        0.003030
# 6        0.113748      0.005880         0.005480        0.001429
# 7        1.117816      0.107335         0.019571        0.001164
# 8        0.036795      0.002059         0.004539        0.000474
# 9        0.339256      0.013428         0.021693        0.004573
# 10       0.037246      0.002785         0.004601        0.000495
# 11       0.381037      0.084731         0.035442        0.019987
# 12       0.048280      0.021661         0.005479        0.002664
# 13       0.387076      0.046295         0.025592        0.012377
# 14       0.047720      0.004947         0.005434        0.001877
# 15       0.343763      0.049302         0.015292        0.003650
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                 100
# 2    squared_error               log2                  10
# 3    squared_error               log2                 100
# 4   absolute_error               sqrt                  10
# 5   absolute_error               sqrt                 100
# 6   absolute_error               log2                  10
# 7   absolute_error               log2                 100
# 8     friedman_mse               sqrt                  10
# 9     friedman_mse               sqrt                 100
# 10    friedman_mse               log2                  10
# 11    friedman_mse               log2                 100
# 12         poisson               sqrt                  10
# 13         poisson               sqrt                 100
# 14         poisson               log2                  10
# 15         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.842693
# 1   {'criterion': 'squared_error', 'max_features':...           0.859745
# 2   {'criterion': 'squared_error', 'max_features':...           0.822211
# 3   {'criterion': 'squared_error', 'max_features':...           0.857512
# 4   {'criterion': 'absolute_error', 'max_features'...           0.849203
# 5   {'criterion': 'absolute_error', 'max_features'...           0.858472
# 6   {'criterion': 'absolute_error', 'max_features'...           0.850695
# 7   {'criterion': 'absolute_error', 'max_features'...           0.857791
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.832232
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.857428
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.847420
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.857357
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.843625
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.857570
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.833973
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.860132
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.765618           0.842917           0.818504
# 1            0.780492           0.862084           0.829214
# 2            0.772238           0.862341           0.818374
# 3            0.780554           0.861040           0.828515
# 4            0.762210           0.824760           0.811085
# 5            0.779241           0.855207           0.832658
# 6            0.763198           0.829159           0.813910
# 7            0.782098           0.858081           0.826626
# 8            0.749189           0.846899           0.809651
# 9            0.783803           0.858726           0.830659
# 10           0.762541           0.832636           0.812235
# 11           0.781659           0.858456           0.825625
# 12           0.755584           0.843142           0.801525
# 13           0.777940           0.858008           0.828823
# 14           0.761593           0.831141           0.797483
# 15           0.779019           0.859681           0.828015
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.836413         0.821229        0.029195                9
# 1            0.839879         0.834283        0.029569                2
# 2            0.818453         0.818724        0.028551               10
# 3            0.840454         0.833615        0.029022                4
# 4            0.826403         0.814732        0.028972               13
# 5            0.841739         0.833463        0.028661                5
# 6            0.830365         0.817465        0.029546               11
# 7            0.844966         0.833912        0.028335                3
# 8            0.827974         0.813189        0.034135               14
# 9            0.843984         0.834920        0.027519                1
# 10           0.797438         0.810454        0.029417               15
# 11           0.838896         0.832398        0.028158                7
# 12           0.830577         0.814891        0.033364               12
# 13           0.839191         0.832306        0.029373                8
# 14           0.823751         0.809588        0.027239               16
# 15           0.835276         0.832425        0.029632                6

# %%
age_input = int(input("Enter the age: "))
bmi_input = float(input("Enter the BMI: "))
children_input = int(input("Enter the number of children: "))
sex_male_input = int(input("Enter 0 if you are male, 1 otherwise: "))
smoker_input = int(input("Enter 0 if you are a smoker, 1 otherwise: "))

# %%
# Create a DataFrame for the input data
input_data = pd.DataFrame({
    'age': [age_input],
    'bmi': [bmi_input],
    'children': [children_input],
    'sex_male': [sex_male_input],
    'smoker_yes': [smoker_input]
})

# %%
# Make predictions using the best model
predictions = GridSearchCV.predict(input_data)
print(f"Predicted insurance charges: {predictions}")
# Out:
# Predicted insurance charges: [6417.6794345]
