# %% [markdown]
# # Classification Assignment
# #### Problem Statement or Requirement:
#
# ###### A requirement from the Hospital, Management asked us to create a predictive model which will predict the Chronic Kidney Disease (CKD) based on the several parameters. The Client has provided the dataset of the same.
#
# ###### 1.) Identify your problem statement
#
# ###### 2.) Tell basic info about the dataset (Total number of rows, columns)
#
# ###### 3.) Mention the pre-processing method if you’re doing any (like converting string to number – nominal data)
#
# ###### 4.) Develop a good model with good evaluation metric. You can use any machine learning algorithm; you can create many models. Finally, you have to come up with final model.
#
# ###### 5.) All the research values of each algorithm should be documented. (You can make tabulation or screenshot of the results.)
#
# ###### 6.) Mention your final model, justify why u have chosen the same.

# %% [markdown]
# 1. The hospital wants a reliable predictive model to classify patients into CKD (Chronic Kidney Disease) or Not CKD, using medical attributes.
# You are tasked with building the best-performing classification model, evaluated using precision, recall, f1-score, and accuracy.
#
# Domain: ML
#
# Type: Supervised Learning
#
# Objective: Binary Classification

# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('CKD.csv')

# %% [markdown]
# 2. Tell basic info about the dataset (Total number of rows, columns)

# %%
print(f"\nRows: {dataset.shape[0]}")
print(f"\nColumns: {dataset.shape[1]}\n\n")

display(dataset)

# Displaying the dataset information
display(dataset.info())
# Out:
# Rows: 399
#
# Columns: 25
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             399 non-null    float64
#  1   bp              399 non-null    float64
#  2   sg              399 non-null    object
#  3   al              399 non-null    float64
#  4   su              399 non-null    float64
#  5   rbc             399 non-null    object
#  6   pc              399 non-null    object
#  7   pcc             399 non-null    object
#  8   ba              399 non-null    object
#  9   bgr             399 non-null    float64
#  10  bu              399 non-null    float64
#  11  sc              399 non-null    float64
#  12  sod             399 non-null    float64
#  13  pot             399 non-null    float64
#  14  hrmo            399 non-null    float64
#  15  pcv             399 non-null    float64
#  16  wc              399 non-null    float64
#  17  rc              399 non-null    float64
#  18  htn             399 non-null    object
#  19  dm              399 non-null    object
#  20  cad             399 non-null    object
#  21  appet           399 non-null    object
#  22  pe              399 non-null    object
#  23  ane             399 non-null    object
#  24  classification  399 non-null    object
# dtypes: float64(13), object(12)
# memory usage: 78.1+ KB
# None

# %% [markdown]
# 3.) Mention the pre-processing method if you’re doing any (like converting string to number – nominal data)

# %%
# Converting categorical variables to numerical
# as the classification column is categorical - ordinal data, will be converted to numerical values using LabelEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# Handle categorical and numerical separately
categorical_cols = dataset.select_dtypes(include='object').columns
numerical_cols = dataset.select_dtypes(exclude='object').columns

# Fill missing values
dataset[categorical_cols] = dataset[categorical_cols].fillna(dataset[categorical_cols].mode().iloc[0])
dataset[numerical_cols] = dataset[numerical_cols].fillna(dataset[numerical_cols].mean())

# Encode categorical columns
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    dataset[col] = le.fit_transform(dataset[col])
    label_encoders[col] = le

# %% [markdown]
# 4. Develop a good model with good evaluation metric. You can use any machine learning algorithm; you can create many models. Finally, you have to come up with final model.
#
# # RandomForest

# %%
# Splitting the dataset into independent and dependent variables
independent = dataset.drop('classification', axis=1)
dependent = dataset['classification']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
StandardScaler = StandardScaler()
X_train = StandardScaler.fit_transform(X_train)
X_test = StandardScaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {'n_estimators':[100, 200, 300],
              'max_features':['auto', 'sqrt', 'log2'],
              'min_samples_split':[2, 5, 10],
              'bootstrap':[True, False]} 



grid = GridSearchCV(RandomForestClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 

# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 2/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=300;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=300;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=300;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=300;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=300;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=300;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=300;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=300;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=300;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_features=auto, min_samples_split=5, n_estimators=300;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=300;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=300;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=300;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=300;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_features=auto, min_samples_split=10, n_estimators=300;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_features=auto, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=1.000 total time=   0.3s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.981 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=1.000 total time=   0.3s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.962 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=1.000 total time=   0.5s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.981 total time=   0.7s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=1.000 total time=   0.6s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.962 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=1.000 total time=   0.6s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.981 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=1.000 total time=   0.7s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=1.000 total time=   0.7s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.962 total time=   0.6s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=1.000 total time=   0.6s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.962 total time=   0.7s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.981 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.962 total time=   0.8s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.981 total time=   0.7s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=1.000 total time=   1.0s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.981 total time=   0.8s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=100;, score=1.000 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.962 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=300;, score=1.000 total time=   0.7s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.981 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.962 total time=   0.6s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=300;, score=1.000 total time=   0.7s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.981 total time=   0.4s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.981 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.962 total time=   0.3s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.962 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=300;, score=1.000 total time=   0.7s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.962 total time=   0.6s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.981 total time=   0.6s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.962 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=100;, score=1.000 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.962 total time=   0.3s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_split=5, n_estimators=300;, score=1.000 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=200;, score=1.000 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.981 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=200;, score=1.000 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.962 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=300;, score=1.000 total time=   0.7s
# [CV 1/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=300;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=300;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=300;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=300;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_features=auto, min_samples_split=2, n_estimators=300;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=300;, score=1.000 total time=   0.6s
# [CV 5/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=300;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=300;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=300;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=300;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_features=auto, min_samples_split=5, n_estimators=300;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=300;, score=nan total time=   0.0s[CV 2/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=300;, score=nan total time=   0.0s
#
# [CV 3/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=300;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=300;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_features=auto, min_samples_split=10, n_estimators=300;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=1.000 total time=   0.1s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.962 total time=   0.7s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=1.000 total time=   0.3s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_split=10, n_estimators=300;, score=1.000 total time=   0.6s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.962 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.962 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.962 total time=   0.1s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=1.000 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.981 total time=   0.5s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.981 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=1.000 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.962 total time=   0.5s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.962 total time=   0.5s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.962 total time=   0.5s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.981 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.942 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.962 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.981 total time=   0.5s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.981 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.942 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.981 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.962 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=1.000 total time=   0.8s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.962 total time=   0.9s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=1.000 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.962 total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=200;, score=1.000 total time=   0.5s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.981 total time=   0.8s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=1.000 total time=   0.5s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.981 total time=   0.5s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.962 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.942 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.981 total time=   0.6s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=200;, score=1.000 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=1.000 total time=   1.0s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=200;, score=1.000 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=200;, score=1.000 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.962 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.962 total time=   0.7s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.981 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.942 total time=   1.1s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=300;, score=1.000 total time=   0.7s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.981 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.962 total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=200;, score=1.000 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.981 total time=   1.0s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=300;, score=1.000 total time=   1.2s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.942 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.981 total time=   0.7s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.981 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.962 total time=   0.8s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.962 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.962 total time=   1.0s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.962 total time=   0.8s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=200;, score=1.000 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_split=5, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=300;, score=1.000 total time=   0.6s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.942 total time=   0.5s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_split=2, n_estimators=300;, score=1.000 total time=   0.6s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.962 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=300;, score=1.000 total time=   0.5s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_split=10, n_estimators=300;, score=1.000 total time=   0.4s
# /home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 90 fits failed out of a total of 270.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 90 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.98480383 0.98104724 0.98104724
#  0.98104724 0.98104724 0.98480383 0.97725344 0.98480061 0.97725344
#  0.98104724 0.98480383 0.98104724 0.98104724 0.98104724 0.98104724
#  0.97725344 0.98104724 0.98480383        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.984899   0.98104724 0.98104724 0.98104724 0.98104724 0.98104724
#  0.97712948 0.97333567 0.97333567 0.98104724 0.98104724 0.98104724
#  0.97712948 0.98104724 0.98480383 0.97725344 0.97712948 0.98088607]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
result = grid.cv_results_
#print(result)
grid_predictions = grid.predict(X_test)

from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, grid_predictions)

# print classification report 
from sklearn.metrics import classification_report
classification_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'bootstrap': False, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}: 1.0

# %%
print("The confusion Matrix:\n", confusion_matrix)
# Out:
# The confusion Matrix:
#  [[51  0]
#  [ 0 82]]

# %%
print("\nThe report using RandomForestClassifier :\n\n\n", classification_report)
# Out:
# The report using RandomForestClassifier :
#
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        51
#            1       1.00      1.00      1.00        82
#
#     accuracy                           1.00       133
#    macro avg       1.00      1.00      1.00       133
# weighted avg       1.00      1.00      1.00       133

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# np.float64(1.0)

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001635      0.000816         0.000000        0.000000
# 1        0.000923      0.000043         0.000000        0.000000
# 2        0.001546      0.000744         0.000000        0.000000
# 3        0.001706      0.000677         0.000000        0.000000
# 4        0.001856      0.000652         0.000000        0.000000
# 5        0.001701      0.000741         0.000000        0.000000
# 6        0.001304      0.000656         0.000000        0.000000
# 7        0.001561      0.000842         0.000000        0.000000
# 8        0.000842      0.000171         0.000000        0.000000
# 9        0.219602      0.018353         0.016579        0.005681
# 10       0.401352      0.042020         0.021883        0.001188
# 11       0.611953      0.035902         0.032682        0.002473
# 12       0.207469      0.010910         0.014963        0.000883
# 13       0.411012      0.011850         0.024017        0.001367
# 14       0.581325      0.036241         0.030644        0.001096
# 15       0.203538      0.011520         0.014280        0.001973
# 16       0.473024      0.102065         0.029976        0.014943
# 17       0.722813      0.153117         0.038488        0.015422
# 18       0.206616      0.030544         0.012927        0.001588
# 19       0.372433      0.004710         0.020964        0.001139
# 20       0.623439      0.039413         0.034056        0.002267
# 21       0.213630      0.027622         0.017573        0.008358
# 22       0.392734      0.020039         0.021366        0.000890
# 23       0.603391      0.032488         0.031635        0.003302
# 24       0.237428      0.021362         0.016605        0.004771
# 25       0.422717      0.016035         0.026327        0.003202
# 26       0.608735      0.022843         0.032136        0.001888
# 27       0.000893      0.000308         0.000000        0.000000
# 28       0.000741      0.000031         0.000000        0.000000
# 29       0.000724      0.000015         0.000000        0.000000
# 30       0.000718      0.000013         0.000000        0.000000
# 31       0.001346      0.000872         0.000000        0.000000
# 32       0.000743      0.000022         0.000000        0.000000
# 33       0.000746      0.000022         0.000000        0.000000
# 34       0.001051      0.000644         0.000000        0.000000
# 35       0.000991      0.000379         0.000000        0.000000
# 36       0.155038      0.014283         0.012480        0.000657
# 37       0.293171      0.018391         0.022268        0.001706
# 38       0.452552      0.003500         0.032578        0.000609
# 39       0.148284      0.006403         0.013777        0.000704
# 40       0.298185      0.026525         0.025383        0.009420
# 41       0.523702      0.108679         0.031392        0.001858
# 42       0.263562      0.073302         0.024995        0.009373
# 43       0.537152      0.216384         0.038806        0.024960
# 44       0.860743      0.213059         0.050712        0.020799
# 45       0.182145      0.021252         0.015332        0.002612
# 46       0.425903      0.051541         0.030830        0.006358
# 47       0.611218      0.087293         0.049003        0.014294
# 48       0.179768      0.031272         0.013373        0.000744
# 49       0.295811      0.005586         0.021362        0.000672
# 50       0.675834      0.226839         0.053622        0.021181
# 51       0.149521      0.002044         0.012411        0.000160
# 52       0.297674      0.006264         0.020954        0.000299
# 53       0.433354      0.079078         0.027347        0.008353
#
#     param_bootstrap param_max_features  param_min_samples_split  \
# 0              True               auto                        2
# 1              True               auto                        2
# 2              True               auto                        2
# 3              True               auto                        5
# 4              True               auto                        5
# 5              True               auto                        5
# 6              True               auto                       10
# 7              True               auto                       10
# 8              True               auto                       10
# 9              True               sqrt                        2
# 10             True               sqrt                        2
# 11             True               sqrt                        2
# 12             True               sqrt                        5
# 13             True               sqrt                        5
# 14             True               sqrt                        5
# 15             True               sqrt                       10
# 16             True               sqrt                       10
# 17             True               sqrt                       10
# 18             True               log2                        2
# 19             True               log2                        2
# 20             True               log2                        2
# 21             True               log2                        5
# 22             True               log2                        5
# 23             True               log2                        5
# 24             True               log2                       10
# 25             True               log2                       10
# 26             True               log2                       10
# 27            False               auto                        2
# 28            False               auto                        2
# 29            False               auto                        2
# 30            False               auto                        5
# 31            False               auto                        5
# 32            False               auto                        5
# 33            False               auto                       10
# 34            False               auto                       10
# 35            False               auto                       10
# 36            False               sqrt                        2
# 37            False               sqrt                        2
# 38            False               sqrt                        2
# 39            False               sqrt                        5
# 40            False               sqrt                        5
# 41            False               sqrt                        5
# 42            False               sqrt                       10
# 43            False               sqrt                       10
# 44            False               sqrt                       10
# 45            False               log2                        2
# 46            False               log2                        2
# 47            False               log2                        2
# 48            False               log2                        5
# 49            False               log2                        5
# 50            False               log2                        5
# 51            False               log2                       10
# 52            False               log2                       10
# 53            False               log2                       10
#
#     param_n_estimators                                             params  \
# 0                  100  {'bootstrap': True, 'max_features': 'auto', 'm...
# 1                  200  {'bootstrap': True, 'max_features': 'auto', 'm...
# 2                  300  {'bootstrap': True, 'max_features': 'auto', 'm...
# 3                  100  {'bootstrap': True, 'max_features': 'auto', 'm...
# 4                  200  {'bootstrap': True, 'max_features': 'auto', 'm...
# 5                  300  {'bootstrap': True, 'max_features': 'auto', 'm...
# 6                  100  {'bootstrap': True, 'max_features': 'auto', 'm...
# 7                  200  {'bootstrap': True, 'max_features': 'auto', 'm...
# 8                  300  {'bootstrap': True, 'max_features': 'auto', 'm...
# 9                  100  {'bootstrap': True, 'max_features': 'sqrt', 'm...
# 10                 200  {'bootstrap': True, 'max_features': 'sqrt', 'm...
# 11                 300  {'bootstrap': True, 'max_features': 'sqrt', 'm...
# 12                 100  {'bootstrap': True, 'max_features': 'sqrt', 'm...
# 13                 200  {'bootstrap': True, 'max_features': 'sqrt', 'm...
# 14                 300  {'bootstrap': True, 'max_features': 'sqrt', 'm...
# 15                 100  {'bootstrap': True, 'max_features': 'sqrt', 'm...
# 16                 200  {'bootstrap': True, 'max_features': 'sqrt', 'm...
# 17                 300  {'bootstrap': True, 'max_features': 'sqrt', 'm...
# 18                 100  {'bootstrap': True, 'max_features': 'log2', 'm...
# 19                 200  {'bootstrap': True, 'max_features': 'log2', 'm...
# 20                 300  {'bootstrap': True, 'max_features': 'log2', 'm...
# 21                 100  {'bootstrap': True, 'max_features': 'log2', 'm...
# 22                 200  {'bootstrap': True, 'max_features': 'log2', 'm...
# 23                 300  {'bootstrap': True, 'max_features': 'log2', 'm...
# 24                 100  {'bootstrap': True, 'max_features': 'log2', 'm...
# 25                 200  {'bootstrap': True, 'max_features': 'log2', 'm...
# 26                 300  {'bootstrap': True, 'max_features': 'log2', 'm...
# 27                 100  {'bootstrap': False, 'max_features': 'auto', '...
# 28                 200  {'bootstrap': False, 'max_features': 'auto', '...
# 29                 300  {'bootstrap': False, 'max_features': 'auto', '...
# 30                 100  {'bootstrap': False, 'max_features': 'auto', '...
# 31                 200  {'bootstrap': False, 'max_features': 'auto', '...
# 32                 300  {'bootstrap': False, 'max_features': 'auto', '...
# 33                 100  {'bootstrap': False, 'max_features': 'auto', '...
# 34                 200  {'bootstrap': False, 'max_features': 'auto', '...
# 35                 300  {'bootstrap': False, 'max_features': 'auto', '...
# 36                 100  {'bootstrap': False, 'max_features': 'sqrt', '...
# 37                 200  {'bootstrap': False, 'max_features': 'sqrt', '...
# 38                 300  {'bootstrap': False, 'max_features': 'sqrt', '...
# 39                 100  {'bootstrap': False, 'max_features': 'sqrt', '...
# 40                 200  {'bootstrap': False, 'max_features': 'sqrt', '...
# 41                 300  {'bootstrap': False, 'max_features': 'sqrt', '...
# 42                 100  {'bootstrap': False, 'max_features': 'sqrt', '...
# 43                 200  {'bootstrap': False, 'max_features': 'sqrt', '...
# 44                 300  {'bootstrap': False, 'max_features': 'sqrt', '...
# 45                 100  {'bootstrap': False, 'max_features': 'log2', '...
# 46                 200  {'bootstrap': False, 'max_features': 'log2', '...
# 47                 300  {'bootstrap': False, 'max_features': 'log2', '...
# 48                 100  {'bootstrap': False, 'max_features': 'log2', '...
# 49                 200  {'bootstrap': False, 'max_features': 'log2', '...
# 50                 300  {'bootstrap': False, 'max_features': 'log2', '...
# 51                 100  {'bootstrap': False, 'max_features': 'log2', '...
# 52                 200  {'bootstrap': False, 'max_features': 'log2', '...
# 53                 300  {'bootstrap': False, 'max_features': 'log2', '...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 1.0           0.961755           1.000000
# 10                1.0           0.961755           0.981217
# 11                1.0           0.961755           0.981217
# 12                1.0           0.961755           0.981217
# 13                1.0           0.961755           0.981217
# 14                1.0           0.961755           1.000000
# 15                1.0           0.961755           0.981217
# 16                1.0           0.961755           0.981217
# 17                1.0           0.961755           0.981217
# 18                1.0           0.961755           0.981217
# 19                1.0           0.961755           1.000000
# 20                1.0           0.961755           0.981217
# 21                1.0           0.961755           0.981217
# 22                1.0           0.961755           0.981217
# 23                1.0           0.961755           0.981217
# 24                1.0           0.961755           0.981217
# 25                1.0           0.961755           0.981217
# 26                1.0           0.961755           1.000000
# 27                NaN                NaN                NaN
# 28                NaN                NaN                NaN
# 29                NaN                NaN                NaN
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
# 32                NaN                NaN                NaN
# 33                NaN                NaN                NaN
# 34                NaN                NaN                NaN
# 35                NaN                NaN                NaN
# 36                1.0           0.981014           0.981217
# 37                1.0           0.961755           0.981217
# 38                1.0           0.961755           0.981217
# 39                1.0           0.961755           0.981217
# 40                1.0           0.961755           0.981217
# 41                1.0           0.961755           0.981217
# 42                1.0           0.942166           0.981217
# 43                1.0           0.942166           0.981217
# 44                1.0           0.942166           0.981217
# 45                1.0           0.961755           0.981217
# 46                1.0           0.961755           0.981217
# 47                1.0           0.961755           0.981217
# 48                1.0           0.942166           0.981217
# 49                1.0           0.961755           0.981217
# 50                1.0           0.961755           1.000000
# 51                1.0           0.961755           0.981217
# 52                1.0           0.942166           0.981217
# 53                1.0           0.942166           1.000000
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0                 NaN                NaN              NaN             NaN
# 1                 NaN                NaN              NaN             NaN
# 2                 NaN                NaN              NaN             NaN
# 3                 NaN                NaN              NaN             NaN
# 4                 NaN                NaN              NaN             NaN
# 5                 NaN                NaN              NaN             NaN
# 6                 NaN                NaN              NaN             NaN
# 7                 NaN                NaN              NaN             NaN
# 8                 NaN                NaN              NaN             NaN
# 9            0.962264           1.000000         0.984804        0.018612
# 10           0.962264           1.000000         0.981047        0.016991
# 11           0.962264           1.000000         0.981047        0.016991
# 12           0.962264           1.000000         0.981047        0.016991
# 13           0.962264           1.000000         0.981047        0.016991
# 14           0.962264           1.000000         0.984804        0.018612
# 15           0.962264           0.981031         0.977253        0.014229
# 16           0.981031           1.000000         0.984801        0.014284
# 17           0.962264           0.981031         0.977253        0.014229
# 18           0.962264           1.000000         0.981047        0.016991
# 19           0.962264           1.000000         0.984804        0.018612
# 20           0.962264           1.000000         0.981047        0.016991
# 21           0.962264           1.000000         0.981047        0.016991
# 22           0.962264           1.000000         0.981047        0.016991
# 23           0.962264           1.000000         0.981047        0.016991
# 24           0.962264           0.981031         0.977253        0.014229
# 25           0.962264           1.000000         0.981047        0.016991
# 26           0.962264           1.000000         0.984804        0.018612
# 27                NaN                NaN              NaN             NaN
# 28                NaN                NaN              NaN             NaN
# 29                NaN                NaN              NaN             NaN
# 30                NaN                NaN              NaN             NaN
# 31                NaN                NaN              NaN             NaN
# 32                NaN                NaN              NaN             NaN
# 33                NaN                NaN              NaN             NaN
# 34                NaN                NaN              NaN             NaN
# 35                NaN                NaN              NaN             NaN
# 36           0.962264           1.000000         0.984899        0.014121
# 37           0.962264           1.000000         0.981047        0.016991
# 38           0.962264           1.000000         0.981047        0.016991
# 39           0.962264           1.000000         0.981047        0.016991
# 40           0.962264           1.000000         0.981047        0.016991
# 41           0.962264           1.000000         0.981047        0.016991
# 42           0.962264           1.000000         0.977129        0.022389
# 43           0.962264           0.981031         0.973336        0.019629
# 44           0.962264           0.981031         0.973336        0.019629
# 45           0.962264           1.000000         0.981047        0.016991
# 46           0.962264           1.000000         0.981047        0.016991
# 47           0.962264           1.000000         0.981047        0.016991
# 48           0.962264           1.000000         0.977129        0.022389
# 49           0.962264           1.000000         0.981047        0.016991
# 50           0.962264           1.000000         0.984804        0.018612
# 51           0.962264           0.981031         0.977253        0.014229
# 52           0.962264           1.000000         0.977129        0.022389
# 53           0.962264           1.000000         0.980886        0.024257
#
#     rank_test_score
# 0                37
# 1                37
# 2                37
# 3                37
# 4                37
# 5                37
# 6                37
# 7                37
# 8                37
# 9                 2
# 10                8
# 11                8
# 12                8
# 13                8
# 14                2
# 15               28
# 16                7
# 17               28
# 18                8
# 19                2
# 20                8
# 21                8
# 22                8
# 23                8
# 24               28
# 25                8
# 26                2
# 27               37
# 28               37
# 29               37
# 30               37
# 31               37
# 32               37
# 33               37
# 34               37
# 35               37
# 36                1
# 37                8
# 38                8
# 39                8
# 40                8
# 41                8
# 42               32
# 43               35
# 44               35
# 45                8
# 46                8
# 47                8
# 48               32
# 49                8
# 50                2
# 51               28
# 52               32
# 53               27

# %%
import pickle
# Save the model to a file
good_fit_model_filename = "random_forest_classification_model.sav"
classification = grid.fit(X_train, y_train)
pickle.dump(classification, open(good_fit_model_filename, 'wb'))
# Load the model from the file
load_good_fit_model = pickle.load(open("random_forest_classification_model.sav", "rb"))
# Ensure the input has all 6 features (including the missing one-hot encoded column for 'State_New York')
result = load_good_fit_model.predict(X_test)
print("Predicted ", result)
# Out:
# Running cells with '.venv (Python 3.12.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/deehub/JoinDeeHub/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
