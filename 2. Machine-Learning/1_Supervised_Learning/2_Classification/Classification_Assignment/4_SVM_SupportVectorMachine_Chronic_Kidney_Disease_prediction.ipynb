# %% [markdown]
# # Classification Assignment
# #### Problem Statement or Requirement:
#
# ###### A requirement from the Hospital, Management asked us to create a predictive model which will predict the Chronic Kidney Disease (CKD) based on the several parameters. The Client has provided the dataset of the same.
#
# ###### 1.) Identify your problem statement
#
# ###### 2.) Tell basic info about the dataset (Total number of rows, columns)
#
# ###### 3.) Mention the pre-processing method if you’re doing any (like converting string to number – nominal data)
#
# ###### 4.) Develop a good model with good evaluation metric. You can use any machine learning algorithm; you can create many models. Finally, you have to come up with final model.
#
# ###### 5.) All the research values of each algorithm should be documented. (You can make tabulation or screenshot of the results.)
#
# ###### 6.) Mention your final model, justify why u have chosen the same.

# %% [markdown]
# 1. The hospital wants a reliable predictive model to classify patients into CKD (Chronic Kidney Disease) or Not CKD, using medical attributes.
# You are tasked with building the best-performing classification model, evaluated using precision, recall, f1-score, and accuracy.
#
# Domain: ML
#
# Type: Supervised Learning
#
# Objective: Binary Classification

# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('CKD.csv')

# %% [markdown]
# 2. Tell basic info about the dataset (Total number of rows, columns)

# %%
print(f"\nRows: {dataset.shape[0]}")
print(f"\nColumns: {dataset.shape[1]}\n\n")

display(dataset)

# Displaying the dataset information
display(dataset.info())
# Out:
# Rows: 399
#
# Columns: 25
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             399 non-null    float64
#  1   bp              399 non-null    float64
#  2   sg              399 non-null    object
#  3   al              399 non-null    float64
#  4   su              399 non-null    float64
#  5   rbc             399 non-null    object
#  6   pc              399 non-null    object
#  7   pcc             399 non-null    object
#  8   ba              399 non-null    object
#  9   bgr             399 non-null    float64
#  10  bu              399 non-null    float64
#  11  sc              399 non-null    float64
#  12  sod             399 non-null    float64
#  13  pot             399 non-null    float64
#  14  hrmo            399 non-null    float64
#  15  pcv             399 non-null    float64
#  16  wc              399 non-null    float64
#  17  rc              399 non-null    float64
#  18  htn             399 non-null    object
#  19  dm              399 non-null    object
#  20  cad             399 non-null    object
#  21  appet           399 non-null    object
#  22  pe              399 non-null    object
#  23  ane             399 non-null    object
#  24  classification  399 non-null    object
# dtypes: float64(13), object(12)
# memory usage: 78.1+ KB
# None

# %% [markdown]
# 3.) Mention the pre-processing method if you’re doing any (like converting string to number – nominal data)

# %%
# Converting categorical variables to numerical
# as the classification column is categorical - ordinal data, will be converted to numerical values using LabelEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# Handle categorical and numerical separately
categorical_cols = dataset.select_dtypes(include='object').columns
numerical_cols = dataset.select_dtypes(exclude='object').columns

# Fill missing values
dataset[categorical_cols] = dataset[categorical_cols].fillna(dataset[categorical_cols].mode().iloc[0])
dataset[numerical_cols] = dataset[numerical_cols].fillna(dataset[numerical_cols].mean())

# Encode categorical columns
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    dataset[col] = le.fit_transform(dataset[col])
    label_encoders[col] = le

# %% [markdown]
# 4. Develop a good model with good evaluation metric. You can use any machine learning algorithm; you can create many models. Finally, you have to come up with final model.
#
# # SVM - Support Vector Machine

# %%
# Splitting the dataset into independent and dependent variables
independent = dataset.drop('classification', axis=1)
dependent = dataset['classification']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
StandardScaler = StandardScaler()
X_train = StandardScaler.fit_transform(X_train)
X_test = StandardScaler.transform(X_test)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

param_grid = {'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
              'probability':[True],
             'C':[0.1, 1, 10, 100]} 



grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 

# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END C=0.1, kernel=linear, probability=True;, score=0.927 total time=   0.0s
# [CV 2/5] END C=0.1, kernel=linear, probability=True;, score=0.981 total time=   0.0s
# [CV 5/5] END C=0.1, kernel=linear, probability=True;, score=0.981 total time=   0.0s
# [CV 1/5] END C=0.1, kernel=poly, probability=True;, score=0.487 total time=   0.0s
# [CV 3/5] END C=0.1, kernel=poly, probability=True;, score=0.478 total time=   0.0s
# [CV 2/5] END C=0.1, kernel=poly, probability=True;, score=0.501 total time=   0.0s
# [CV 4/5] END C=0.1, kernel=poly, probability=True;, score=0.478 total time=   0.0s
# [CV 5/5] END C=0.1, kernel=poly, probability=True;, score=0.478 total time=   0.0s
# [CV 1/5] END C=0.1, kernel=rbf, probability=True;, score=0.927 total time=   0.0s
# [CV 2/5] END C=0.1, kernel=rbf, probability=True;, score=0.962 total time=   0.0s
# [CV 3/5] END C=0.1, kernel=rbf, probability=True;, score=0.944 total time=   0.0s
# [CV 4/5] END C=0.1, kernel=rbf, probability=True;, score=1.000 total time=   0.0s
# [CV 5/5] END C=0.1, kernel=rbf, probability=True;, score=0.981 total time=   0.0s
# [CV 1/5] END C=0.1, kernel=sigmoid, probability=True;, score=0.927 total time=   0.0s
# [CV 2/5] END C=0.1, kernel=sigmoid, probability=True;, score=0.963 total time=   0.0s
# [CV 3/5] END C=0.1, kernel=sigmoid, probability=True;, score=0.944 total time=   0.0s
# [CV 4/5] END C=0.1, kernel=sigmoid, probability=True;, score=0.981 total time=   0.0s
# [CV 1/5] END C=1, kernel=linear, probability=True;, score=0.909 total time=   0.0s
# [CV 5/5] END C=0.1, kernel=sigmoid, probability=True;, score=0.981 total time=   0.0s
# [CV 2/5] END C=1, kernel=linear, probability=True;, score=1.000 total time=   0.0s
# [CV 3/5] END C=1, kernel=linear, probability=True;, score=0.963 total time=   0.0s
# [CV 5/5] END C=1, kernel=linear, probability=True;, score=0.981 total time=   0.0s
# [CV 4/5] END C=1, kernel=linear, probability=True;, score=0.981 total time=   0.0s
# [CV 1/5] END C=1, kernel=poly, probability=True;, score=0.963 total time=   0.0s
# [CV 2/5] END C=1, kernel=poly, probability=True;, score=0.942 total time=   0.0s
# [CV 4/5] END C=1, kernel=poly, probability=True;, score=0.922 total time=   0.0s
# [CV 3/5] END C=1, kernel=poly, probability=True;, score=0.981 total time=   0.0s
# [CV 5/5] END C=1, kernel=poly, probability=True;, score=0.962 total time=   0.0s
# [CV 1/5] END .C=1, kernel=rbf, probability=True;, score=0.927 total time=   0.0s
# [CV 3/5] END .C=1, kernel=rbf, probability=True;, score=0.963 total time=   0.0s
# [CV 2/5] END .C=1, kernel=rbf, probability=True;, score=0.981 total time=   0.0s
# [CV 4/5] END .C=1, kernel=rbf, probability=True;, score=1.000 total time=   0.0s
# [CV 5/5] END .C=1, kernel=rbf, probability=True;, score=1.000 total time=   0.0s
# [CV 2/5] END C=1, kernel=sigmoid, probability=True;, score=1.000 total time=   0.0s
# [CV 1/5] END C=1, kernel=sigmoid, probability=True;, score=0.927 total time=   0.0s
# [CV 3/5] END C=1, kernel=sigmoid, probability=True;, score=0.963 total time=   0.0s
# [CV 1/5] END C=10, kernel=linear, probability=True;, score=0.927 total time=   0.0s[CV 4/5] END C=1, kernel=sigmoid, probability=True;, score=1.000 total time=   0.0s
#
# [CV 2/5] END C=10, kernel=linear, probability=True;, score=1.000 total time=   0.0s
# [CV 3/5] END C=10, kernel=linear, probability=True;, score=0.981 total time=   0.0s
# [CV 5/5] END C=1, kernel=sigmoid, probability=True;, score=0.981 total time=   0.0s
# [CV 4/5] END C=10, kernel=linear, probability=True;, score=1.000 total time=   0.0s
# [CV 4/5] END C=10, kernel=poly, probability=True;, score=0.981 total time=   0.0s
# [CV 5/5] END C=10, kernel=linear, probability=True;, score=1.000 total time=   0.0s
# [CV 5/5] END C=10, kernel=poly, probability=True;, score=1.000 total time=   0.0s
# [CV 1/5] END C=10, kernel=rbf, probability=True;, score=0.927 total time=   0.0s
# [CV 1/5] END C=10, kernel=poly, probability=True;, score=0.963 total time=   0.0s
# [CV 2/5] END C=10, kernel=rbf, probability=True;, score=0.981 total time=   0.0s
# [CV 3/5] END C=10, kernel=rbf, probability=True;, score=0.963 total time=   0.0s
# [CV 4/5] END C=10, kernel=rbf, probability=True;, score=0.981 total time=   0.0s
# [CV 5/5] END C=10, kernel=rbf, probability=True;, score=1.000 total time=   0.0s
# [CV 2/5] END C=10, kernel=poly, probability=True;, score=0.981 total time=   0.0s
# [CV 1/5] END C=10, kernel=sigmoid, probability=True;, score=0.909 total time=   0.0s
# [CV 2/5] END C=10, kernel=sigmoid, probability=True;, score=0.981 total time=   0.0s
# [CV 3/5] END C=10, kernel=poly, probability=True;, score=0.981 total time=   0.0s
# [CV 3/5] END C=10, kernel=sigmoid, probability=True;, score=0.981 total time=   0.0s
# [CV 4/5] END C=10, kernel=sigmoid, probability=True;, score=0.981 total time=   0.0s
# [CV 1/5] END C=100, kernel=linear, probability=True;, score=0.927 total time=   0.0s
# [CV 5/5] END C=10, kernel=sigmoid, probability=True;, score=0.981 total time=   0.0s
# [CV 2/5] END C=100, kernel=linear, probability=True;, score=1.000 total time=   0.0s
# [CV 5/5] END C=100, kernel=linear, probability=True;, score=1.000 total time=   0.0s
# [CV 3/5] END C=100, kernel=linear, probability=True;, score=0.981 total time=   0.0s
# [CV 1/5] END C=100, kernel=poly, probability=True;, score=0.927 total time=   0.0s
# [CV 4/5] END C=100, kernel=linear, probability=True;, score=1.000 total time=   0.0s
# [CV 2/5] END C=100, kernel=poly, probability=True;, score=0.962 total time=   0.0s
# [CV 3/5] END C=100, kernel=poly, probability=True;, score=0.981 total time=   0.0s
# [CV 4/5] END C=100, kernel=poly, probability=True;, score=0.981 total time=   0.0s
# [CV 3/5] END C=100, kernel=rbf, probability=True;, score=0.981 total time=   0.0s
# [CV 5/5] END C=100, kernel=poly, probability=True;, score=1.000 total time=   0.0s
# [CV 4/5] END C=100, kernel=rbf, probability=True;, score=0.981 total time=   0.0s
# [CV 5/5] END C=100, kernel=rbf, probability=True;, score=1.000 total time=   0.0s
# [CV 1/5] END C=100, kernel=rbf, probability=True;, score=0.927 total time=   0.0s
# [CV 1/5] END C=100, kernel=sigmoid, probability=True;, score=0.927 total time=   0.0s
# [CV 2/5] END C=100, kernel=rbf, probability=True;, score=0.981 total time=   0.0s
# [CV 2/5] END C=100, kernel=sigmoid, probability=True;, score=0.981 total time=   0.0s
# [CV 4/5] END C=100, kernel=sigmoid, probability=True;, score=0.981 total time=   0.0s
# [CV 5/5] END C=100, kernel=sigmoid, probability=True;, score=0.962 total time=   0.0s
# [CV 3/5] END C=100, kernel=sigmoid, probability=True;, score=0.981 total time=   0.0s
# [CV 3/5] END C=0.1, kernel=linear, probability=True;, score=0.963 total time=   0.0s
# [CV 4/5] END C=0.1, kernel=linear, probability=True;, score=0.981 total time=   0.0s
# GridSearchCV(estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#                          'probability': [True]},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
result = grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, grid_predictions)



# print classification report 
from sklearn.metrics import classification_report
classification_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 10, 'kernel': 'linear', 'probability': True}: 0.9624731911379497

# %%
print("The confusion Matrix:\n",confusion_matrix)
# Out:
# The confusion Matrix:
#  [[49  2]
#  [ 3 79]]

# %%
print("\nThe report using SVC :\n\n\n",classification_report)
# Out:
# The report using SVC :
#
#
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        51
#            1       0.98      0.96      0.97        82
#
#     accuracy                           0.96       133
#    macro avg       0.96      0.96      0.96       133
# weighted avg       0.96      0.96      0.96       133

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, grid.predict_proba(X_test)[:, 1])
# Out:
# np.float64(0.996652319464371)

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.007195      0.001941         0.005921        0.001436      0.1
# 1        0.014179      0.003742         0.004372        0.000765      0.1
# 2        0.011974      0.001048         0.003658        0.000169      0.1
# 3        0.013122      0.001510         0.003855        0.000675      0.1
# 4        0.005723      0.002045         0.003484        0.000174      1.0
# 5        0.010500      0.000679         0.003460        0.000104      1.0
# 6        0.006261      0.000705         0.003729        0.000438      1.0
# 7        0.009659      0.003656         0.003812        0.001001      1.0
# 8        0.004873      0.000776         0.004355        0.002377     10.0
# 9        0.013997      0.004654         0.005763        0.002740     10.0
# 10       0.004683      0.000367         0.003202        0.000075     10.0
# 11       0.005629      0.000991         0.003409        0.000448     10.0
# 12       0.005076      0.000735         0.004511        0.002330    100.0
# 13       0.010425      0.003698         0.004510        0.001361    100.0
# 14       0.006362      0.001346         0.005012        0.001859    100.0
# 15       0.006982      0.003255         0.004187        0.001697    100.0
#
#    param_kernel  param_probability  \
# 0        linear               True
# 1          poly               True
# 2           rbf               True
# 3       sigmoid               True
# 4        linear               True
# 5          poly               True
# 6           rbf               True
# 7       sigmoid               True
# 8        linear               True
# 9          poly               True
# 10          rbf               True
# 11      sigmoid               True
# 12       linear               True
# 13         poly               True
# 14          rbf               True
# 15      sigmoid               True
#
#                                                params  split0_test_score  \
# 0   {'C': 0.1, 'kernel': 'linear', 'probability': ...           0.926978
# 1   {'C': 0.1, 'kernel': 'poly', 'probability': True}           0.486532
# 2    {'C': 0.1, 'kernel': 'rbf', 'probability': True}           0.926978
# 3   {'C': 0.1, 'kernel': 'sigmoid', 'probability':...           0.926978
# 4   {'C': 1, 'kernel': 'linear', 'probability': True}           0.908877
# 5     {'C': 1, 'kernel': 'poly', 'probability': True}           0.962517
# 6      {'C': 1, 'kernel': 'rbf', 'probability': True}           0.926978
# 7   {'C': 1, 'kernel': 'sigmoid', 'probability': T...           0.926978
# 8   {'C': 10, 'kernel': 'linear', 'probability': T...           0.926978
# 9    {'C': 10, 'kernel': 'poly', 'probability': True}           0.963284
# 10    {'C': 10, 'kernel': 'rbf', 'probability': True}           0.926978
# 11  {'C': 10, 'kernel': 'sigmoid', 'probability': ...           0.908877
# 12  {'C': 100, 'kernel': 'linear', 'probability': ...           0.926978
# 13  {'C': 100, 'kernel': 'poly', 'probability': True}           0.926978
# 14   {'C': 100, 'kernel': 'rbf', 'probability': True}           0.926978
# 15  {'C': 100, 'kernel': 'sigmoid', 'probability':...           0.926978
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.981233           0.962573           0.981217
# 1            0.501410           0.477841           0.477841
# 2            0.962264           0.944023           1.000000
# 3            0.962636           0.944023           0.981217
# 4            1.000000           0.962573           0.981217
# 5            0.942166           0.981217           0.922492
# 6            0.981014           0.962573           1.000000
# 7            1.000000           0.962573           1.000000
# 8            1.000000           0.981217           1.000000
# 9            0.981014           0.981217           0.981031
# 10           0.981014           0.962573           0.981031
# 11           0.981233           0.981217           0.981217
# 12           1.000000           0.981217           1.000000
# 13           0.962264           0.981217           0.981217
# 14           0.981014           0.981217           0.981031
# 15           0.981014           0.981217           0.981217
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.981217         0.966644        0.021107               11
# 1            0.477841         0.484293        0.009196               16
# 2            0.981217         0.962896        0.025919               13
# 3            0.981217         0.959214        0.021213               14
# 4            0.981217         0.966777        0.031276                9
# 5            0.962264         0.954131        0.020072               15
# 6            1.000000         0.974113        0.027360                5
# 7            0.981217         0.974154        0.027370                4
# 8            1.000000         0.981639        0.028282                1
# 9            1.000000         0.981309        0.011614                3
# 10           1.000000         0.970319        0.024692                8
# 11           0.981217         0.966752        0.028938               10
# 12           1.000000         0.981639        0.028282                1
# 13           1.000000         0.970335        0.024746                7
# 14           1.000000         0.974048        0.024649                6
# 15           0.962264         0.966538        0.021089               12
