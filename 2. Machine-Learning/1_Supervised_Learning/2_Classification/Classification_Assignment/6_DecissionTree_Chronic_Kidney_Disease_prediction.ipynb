# %% [markdown]
# # Classification Assignment
# #### Problem Statement or Requirement:
#
# ###### A requirement from the Hospital, Management asked us to create a predictive model which will predict the Chronic Kidney Disease (CKD) based on the several parameters. The Client has provided the dataset of the same.
#
# ###### 1.) Identify your problem statement
#
# ###### 2.) Tell basic info about the dataset (Total number of rows, columns)
#
# ###### 3.) Mention the pre-processing method if you’re doing any (like converting string to number – nominal data)
#
# ###### 4.) Develop a good model with good evaluation metric. You can use any machine learning algorithm; you can create many models. Finally, you have to come up with final model.
#
# ###### 5.) All the research values of each algorithm should be documented. (You can make tabulation or screenshot of the results.)
#
# ###### 6.) Mention your final model, justify why u have chosen the same.

# %% [markdown]
# 1. The hospital wants a reliable predictive model to classify patients into CKD (Chronic Kidney Disease) or Not CKD, using medical attributes.
# You are tasked with building the best-performing classification model, evaluated using precision, recall, f1-score, and accuracy.
#
# Domain: ML
#
# Type: Supervised Learning
#
# Objective: Binary Classification

# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('CKD.csv')

# %% [markdown]
# 2. Tell basic info about the dataset (Total number of rows, columns)

# %%
print(f"\nRows: {dataset.shape[0]}")
print(f"\nColumns: {dataset.shape[1]}\n\n")

display(dataset)

# Displaying the dataset information
display(dataset.info())
# Out:
# Rows: 399
#
# Columns: 25
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             399 non-null    float64
#  1   bp              399 non-null    float64
#  2   sg              399 non-null    object
#  3   al              399 non-null    float64
#  4   su              399 non-null    float64
#  5   rbc             399 non-null    object
#  6   pc              399 non-null    object
#  7   pcc             399 non-null    object
#  8   ba              399 non-null    object
#  9   bgr             399 non-null    float64
#  10  bu              399 non-null    float64
#  11  sc              399 non-null    float64
#  12  sod             399 non-null    float64
#  13  pot             399 non-null    float64
#  14  hrmo            399 non-null    float64
#  15  pcv             399 non-null    float64
#  16  wc              399 non-null    float64
#  17  rc              399 non-null    float64
#  18  htn             399 non-null    object
#  19  dm              399 non-null    object
#  20  cad             399 non-null    object
#  21  appet           399 non-null    object
#  22  pe              399 non-null    object
#  23  ane             399 non-null    object
#  24  classification  399 non-null    object
# dtypes: float64(13), object(12)
# memory usage: 78.1+ KB
# None

# %% [markdown]
# 3.) Mention the pre-processing method if you’re doing any (like converting string to number – nominal data)

# %%
# Converting categorical variables to numerical
# as the classification column is categorical - ordinal data, will be converted to numerical values using LabelEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# Handle categorical and numerical separately
categorical_cols = dataset.select_dtypes(include='object').columns
numerical_cols = dataset.select_dtypes(exclude='object').columns

# Fill missing values
dataset[categorical_cols] = dataset[categorical_cols].fillna(dataset[categorical_cols].mode().iloc[0])
dataset[numerical_cols] = dataset[numerical_cols].fillna(dataset[numerical_cols].mean())

# Encode categorical columns
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    dataset[col] = le.fit_transform(dataset[col])
    label_encoders[col] = le

# %% [markdown]
# 4. Develop a good model with good evaluation metric. You can use any machine learning algorithm; you can create many models. Finally, you have to come up with final model.
#
# # DecissionTree

# %%
# Splitting the dataset into independent and dependent variables
independent = dataset.drop('classification', axis=1)
dependent = dataset['classification']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
StandardScaler = StandardScaler()
X_train = StandardScaler.fit_transform(X_train)
X_test = StandardScaler.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['gini', 'entropy'],
              'max_depth':[None, 10, 20, 30],
              'min_samples_split':[2, 5, 10],
              'min_samples_leaf':[1, 2, 4]} 

grid = GridSearchCV(DecisionTreeClassifier(), param_grid, refit = True, verbose = 3, n_jobs=-1, scoring='f1_weighted') 

# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.963 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=1.000 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=1.000 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.942 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.963 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.942 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2;, score=0.907 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2;, score=0.922 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5;, score=0.963 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2;, score=0.942 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10;, score=0.927 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s[CV 5/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10;, score=0.981 total time=   0.0s
#
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2;, score=0.927 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5;, score=0.927 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10;, score=0.851 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.942 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=1.000 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5;, score=0.962 total time=   0.0s[CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.981 total time=   0.0s
#
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10;, score=0.907 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5;, score=0.963 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2;, score=0.963 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5;, score=0.870 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5;, score=0.942 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2;, score=0.922 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10;, score=0.927 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2;, score=0.943 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10;, score=0.851 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10;, score=0.943 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.963 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=1.000 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2;, score=0.907 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2;, score=0.922 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.963 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2;, score=0.942 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.943 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10;, score=0.945 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.924 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2;, score=0.927 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2;, score=0.943 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2;, score=0.870 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5;, score=0.963 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5;, score=0.981 total time=   0.0s[CV 4/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10;, score=0.922 total time=   0.0s
#
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2;, score=0.922 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5;, score=0.963 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=10;, score=0.942 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5;, score=0.943 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5;, score=0.927 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10;, score=1.000 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10;, score=0.927 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10;, score=1.000 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5;, score=0.944 total time=   0.0s[CV 2/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
#
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10;, score=0.851 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5;, score=0.962 total time=   0.0s[CV 5/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=10;, score=0.942 total time=   0.0s
#
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2;, score=0.963 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5;, score=0.870 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_leaf=1, min_samples_split=2;, score=0.945 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10;, score=0.927 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.891 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5;, score=0.891 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.907 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10;, score=0.851 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.942 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.924 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_leaf=2, min_samples_split=10;, score=0.942 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.891 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.927 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5;, score=0.942 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2;, score=0.927 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.925 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5;, score=1.000 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.963 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10;, score=0.891 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.922 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10;, score=0.942 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5;, score=1.000 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2;, score=0.891 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5;, score=0.981 total time=   0.0s[CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2;, score=0.962 total time=   0.0s
#
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2;, score=0.909 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10;, score=0.927 total time=   0.0s[CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2;, score=0.944 total time=   0.0s
#
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2;, score=0.942 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.891 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s[CV 3/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10;, score=0.851 total time=   0.0s
#
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2;, score=0.922 total time=   0.0s[CV 4/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10;, score=0.922 total time=   0.0s
#
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5;, score=0.942 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5;, score=1.000 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=1.000 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.909 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5;, score=0.909 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10;, score=0.891 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.942 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10;, score=0.907 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.963 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10;, score=0.942 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.922 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2;, score=0.872 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5;, score=0.872 total time=   0.0s[CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2;, score=0.927 total time=   0.0s
#
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2;, score=0.907 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2;, score=0.922 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5;, score=0.909 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2;, score=0.942 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5;, score=0.891 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10;, score=0.927 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10;, score=0.851 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.891 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5;, score=0.944 total time=   0.0s[CV 2/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.962 total time=   0.0s
#
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.942 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.922 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5;, score=0.891 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.891 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.963 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.922 total time=   0.0s[CV 2/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2;, score=0.962 total time=   0.0s
#
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2;, score=0.872 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2;, score=0.942 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=5;, score=0.891 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=5;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=5;, score=0.942 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10;, score=0.942 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10;, score=0.891 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2;, score=0.927 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=10;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5;, score=0.909 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=2;, score=0.922 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10;, score=0.927 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10;, score=0.851 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_leaf=4, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=2;, score=0.943 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=2;, score=0.872 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=2;, score=0.922 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=5;, score=0.891 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=10;, score=0.962 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=5;, score=0.942 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=10;, score=1.000 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=10;, score=0.891 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=2;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=10;, score=0.922 total time=   0.0s[CV 1/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=2;, score=0.891 total time=   0.0s
#
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=2;, score=0.942 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=2;, score=0.962 total time=   0.0s[CV 5/5] END criterion=entropy, max_depth=30, min_samples_leaf=1, min_samples_split=10;, score=0.981 total time=   0.0s
#
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=2;, score=0.962 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=5;, score=0.942 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=10;, score=0.891 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=5;, score=0.962 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=5;, score=0.907 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=5;, score=0.891 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=10;, score=0.907 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=10;, score=0.942 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_leaf=2, min_samples_split=10;, score=0.942 total time=   0.0s[CV 4/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=2;, score=0.922 total time=   0.0s
#
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=2;, score=0.927 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=2;, score=0.944 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=2;, score=0.981 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=5;, score=0.909 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=5;, score=0.981 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=5;, score=0.944 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=10;, score=0.927 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=10;, score=0.944 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=5;, score=0.922 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=10;, score=0.851 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=10;, score=0.922 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_leaf=4, min_samples_split=10;, score=0.962 total time=   0.0s
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
result = grid.cv_results_
#print(result)
grid_predictions = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, grid_predictions)


# print classification report 
from sklearn.metrics import classification_report
classification_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}: 0.9329951419775407

# %%
print("The confusion Matrix:\n", confusion_matrix)
# Out:
# The confusion Matrix:
#  [[50  1]
#  [ 8 74]]

# %%
print("\nThe report using DecisionTreeClassifier :\n\n\n", classification_report)
# Out:
# The report using DecisionTreeClassifier :
#
#
#                precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92        51
#            1       0.99      0.90      0.94        82
#
#     accuracy                           0.93       133
#    macro avg       0.92      0.94      0.93       133
# weighted avg       0.94      0.93      0.93       133

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# np.float64(0.9414155906264944)

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006606      0.002411         0.006226        0.002904
# 1        0.005109      0.001517         0.004347        0.000801
# 2        0.007660      0.003813         0.004592        0.001077
# 3        0.003110      0.001142         0.005060        0.001886
# 4        0.002359      0.000189         0.003691        0.000377
# ..            ...           ...              ...             ...
# 67       0.002797      0.001292         0.003997        0.001413
# 68       0.002738      0.000631         0.003049        0.000111
# 69       0.002595      0.000661         0.003039        0.000058
# 70       0.002462      0.000432         0.004257        0.000939
# 71       0.002161      0.000623         0.002725        0.000868
#
#    param_criterion param_max_depth  param_min_samples_leaf  \
# 0             gini            None                       1
# 1             gini            None                       1
# 2             gini            None                       1
# 3             gini            None                       2
# 4             gini            None                       2
# ..             ...             ...                     ...
# 67         entropy              30                       2
# 68         entropy              30                       2
# 69         entropy              30                       4
# 70         entropy              30                       4
# 71         entropy              30                       4
#
#     param_min_samples_split  \
# 0                         2
# 1                         5
# 2                        10
# 3                         2
# 4                         5
# ..                      ...
# 67                        5
# 68                       10
# 69                        2
# 70                        5
# 71                       10
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': None, 'min_...           0.962963
# 1   {'criterion': 'gini', 'max_depth': None, 'min_...           0.981378
# 2   {'criterion': 'gini', 'max_depth': None, 'min_...           0.981378
# 3   {'criterion': 'gini', 'max_depth': None, 'min_...           0.981378
# 4   {'criterion': 'gini', 'max_depth': None, 'min_...           0.962963
# ..                                                ...                ...
# 67  {'criterion': 'entropy', 'max_depth': 30, 'min...           0.890759
# 68  {'criterion': 'entropy', 'max_depth': 30, 'min...           0.890759
# 69  {'criterion': 'entropy', 'max_depth': 30, 'min...           0.926567
# 70  {'criterion': 'entropy', 'max_depth': 30, 'min...           0.908501
# 71  {'criterion': 'entropy', 'max_depth': 30, 'min...           0.926567
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            1.000000           1.000000           0.961826
# 1            1.000000           1.000000           0.922492
# 2            0.962264           0.962573           0.922492
# 3            0.962264           0.907035           0.922492
# 4            0.943699           0.981217           0.922492
# ..                ...                ...                ...
# 67           0.943699           0.907035           0.942332
# 68           0.943699           0.907035           0.942332
# 69           0.944161           0.944023           0.922492
# 70           0.944161           0.944023           0.922492
# 71           0.944161           0.851225           0.922492
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.962264         0.977411        0.018448                1
# 1            0.942332         0.969240        0.031462                6
# 2            0.942332         0.954208        0.020100               24
# 3            0.942332         0.943100        0.026678               45
# 4            0.981031         0.958280        0.022623               17
# ..                ...              ...             ...              ...
# 67           0.961826         0.929130        0.026139               63
# 68           0.942332         0.925232        0.022115               67
# 69           0.981217         0.943692        0.020742               40
# 70           0.981217         0.940079        0.024621               50
# 71           0.961826         0.921254        0.037695               69
#
# [72 rows x 17 columns]
