# %% [markdown]
# #gridsearchCV_Random_forest_regression

# %%
import pandas as pd

# %%
#load the dataset
dataset = pd.read_csv('insurance_pre.csv')

#dummy the categorical variables
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)
# Display the first few rows of the dataset
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
# Define the features and target variable
independent = dataset.drop('charges', axis=1)  
#print(independent)
dependent = dataset['charges']

# %%
# Import necessary libraries for model training and evaluation
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
# Initialize the RandomForestRegressor with GridSearchCV
# Create a GridSearchCV object with RandomForestRegressor
GridSearchCV = GridSearchCV(
    estimator=RandomForestRegressor(),
    param_grid={
        'n_estimators': [10, 100],
        'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
        'max_features': ['sqrt', 'log2']
    },
    refit=True,
    verbose=3,
    n_jobs=-1
)

# Fit the model using GridSearchCV
GridSearchCV.fit(independent, dependent)


# R2score value for best parameters
print(f"GridSearchCV Results R2score value for best parameters: {GridSearchCV.best_params_}")
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 2/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.759 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.828 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.849 total time=   0.1s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.841 total time=   0.1s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, n_estimators=10;, score=0.815 total time=   0.1s
# [CV 1/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.856 total time=   0.4s
# [CV 2/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.776 total time=   0.5s
# [CV 1/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.848 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.863 total time=   0.4s
# [CV 2/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.763 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.839 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.807 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=log2, n_estimators=10;, score=0.821 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.840 total time=   0.3s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, n_estimators=100;, score=0.830 total time=   0.4s
# [CV 2/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.779 total time=   0.3s
# [CV 1/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.858 total time=   0.6s
# [CV 3/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.861 total time=   0.6s
# [CV 5/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.840 total time=   0.3s
# [CV 4/5] END criterion=squared_error, max_features=log2, n_estimators=100;, score=0.831 total time=   0.7s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.837 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.846 total time=   0.2s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.826 total time=   0.1s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.760 total time=   0.2s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.813 total time=   0.2s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.856 total time=   1.1s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.779 total time=   1.1s
# [CV 1/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.843 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.851 total time=   1.3s
# [CV 2/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.759 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.805 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.816 total time=   0.2s
# [CV 5/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.847 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.828 total time=   1.8s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.842 total time=   1.3s
# [CV 2/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.781 total time=   1.0s
# [CV 1/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.855 total time=   1.1s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=10;, score=0.836 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=10;, score=0.768 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=10;, score=0.860 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=10;, score=0.801 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=10;, score=0.827 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.856 total time=   1.2s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=100;, score=0.857 total time=   0.5s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=100;, score=0.783 total time=   0.4s
# [CV 4/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.829 total time=   1.2s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=100;, score=0.863 total time=   0.3s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, n_estimators=10;, score=0.836 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, n_estimators=10;, score=0.759 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.845 total time=   1.2s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, n_estimators=10;, score=0.837 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, n_estimators=10;, score=0.841 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, n_estimators=10;, score=0.806 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=100;, score=0.829 total time=   0.5s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, n_estimators=100;, score=0.837 total time=   0.5s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, n_estimators=100;, score=0.860 total time=   0.3s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, n_estimators=100;, score=0.778 total time=   0.4s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, n_estimators=100;, score=0.858 total time=   0.4s
# [CV 2/5] END criterion=poisson, max_features=sqrt, n_estimators=10;, score=0.772 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=sqrt, n_estimators=10;, score=0.847 total time=   0.1s
# [CV 3/5] END criterion=poisson, max_features=sqrt, n_estimators=10;, score=0.857 total time=   0.1s
# [CV 4/5] END criterion=poisson, max_features=sqrt, n_estimators=10;, score=0.823 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_features=sqrt, n_estimators=10;, score=0.817 total time=   0.1s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, n_estimators=100;, score=0.840 total time=   0.4s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, n_estimators=100;, score=0.827 total time=   0.6s
# [CV 1/5] END criterion=poisson, max_features=sqrt, n_estimators=100;, score=0.857 total time=   0.4s
# [CV 2/5] END criterion=poisson, max_features=sqrt, n_estimators=100;, score=0.781 total time=   0.6s
# [CV 1/5] END criterion=poisson, max_features=log2, n_estimators=10;, score=0.832 total time=   0.1s
# [CV 2/5] END criterion=poisson, max_features=log2, n_estimators=10;, score=0.770 total time=   0.1s
# [CV 3/5] END criterion=poisson, max_features=sqrt, n_estimators=100;, score=0.858 total time=   0.6s
# [CV 3/5] END criterion=poisson, max_features=log2, n_estimators=10;, score=0.844 total time=   0.1s
# [CV 4/5] END criterion=poisson, max_features=log2, n_estimators=10;, score=0.815 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_features=log2, n_estimators=10;, score=0.827 total time=   0.1s
# [CV 4/5] END criterion=poisson, max_features=sqrt, n_estimators=100;, score=0.826 total time=   1.0s
# [CV 1/5] END criterion=poisson, max_features=log2, n_estimators=100;, score=0.856 total time=   0.4s
# [CV 5/5] END criterion=poisson, max_features=sqrt, n_estimators=100;, score=0.840 total time=   1.3s
# [CV 4/5] END criterion=poisson, max_features=log2, n_estimators=100;, score=0.830 total time=   0.4s
# [CV 2/5] END criterion=poisson, max_features=log2, n_estimators=100;, score=0.777 total time=   0.9s
# [CV 3/5] END criterion=poisson, max_features=log2, n_estimators=100;, score=0.863 total time=   0.9s
# [CV 5/5] END criterion=poisson, max_features=log2, n_estimators=100;, score=0.839 total time=   0.5s
# GridSearchCV Results R2score value for best parameters: {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}

# %%
# Get the results from GridSearchCV
Results = GridSearchCV.cv_results_
# Convert the results to a DataFrame for better readability
Results_df = pd.DataFrame.from_dict(Results)
Results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.054779      0.017450         0.006362        0.002419
# 1        0.368352      0.043936         0.023389        0.006695
# 2        0.038026      0.002285         0.004883        0.001231
# 3        0.503655      0.146930         0.021271        0.002816
# 4        0.166918      0.052767         0.005291        0.000951
# 5        1.308255      0.224694         0.026680        0.010481
# 6        0.129365      0.046759         0.004086        0.000397
# 7        1.109230      0.058737         0.019663        0.001239
# 8        0.032977      0.000390         0.003964        0.000187
# 9        0.411688      0.052041         0.023730        0.005460
# 10       0.037251      0.003985         0.004580        0.000592
# 11       0.403101      0.080099         0.028821        0.009279
# 12       0.073318      0.026713         0.008234        0.003881
# 13       0.725918      0.282038         0.052952        0.031808
# 14       0.077873      0.028449         0.007295        0.004374
# 15       0.598689      0.217837         0.019225        0.000470
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                 100
# 2    squared_error               log2                  10
# 3    squared_error               log2                 100
# 4   absolute_error               sqrt                  10
# 5   absolute_error               sqrt                 100
# 6   absolute_error               log2                  10
# 7   absolute_error               log2                 100
# 8     friedman_mse               sqrt                  10
# 9     friedman_mse               sqrt                 100
# 10    friedman_mse               log2                  10
# 11    friedman_mse               log2                 100
# 12         poisson               sqrt                  10
# 13         poisson               sqrt                 100
# 14         poisson               log2                  10
# 15         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.849212
# 1   {'criterion': 'squared_error', 'max_features':...           0.856368
# 2   {'criterion': 'squared_error', 'max_features':...           0.848216
# 3   {'criterion': 'squared_error', 'max_features':...           0.857650
# 4   {'criterion': 'absolute_error', 'max_features'...           0.846065
# 5   {'criterion': 'absolute_error', 'max_features'...           0.855843
# 6   {'criterion': 'absolute_error', 'max_features'...           0.843396
# 7   {'criterion': 'absolute_error', 'max_features'...           0.855258
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.836481
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.857390
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.835890
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.859747
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.846642
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.857080
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.831536
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.856332
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.759230           0.840618           0.814704
# 1            0.776464           0.862646           0.829966
# 2            0.763475           0.838823           0.807454
# 3            0.778742           0.861319           0.831291
# 4            0.759635           0.836809           0.812944
# 5            0.778704           0.851265           0.827924
# 6            0.759243           0.815968           0.804870
# 7            0.781141           0.855887           0.829364
# 8            0.768074           0.860356           0.801353
# 9            0.783129           0.862561           0.828595
# 10           0.759384           0.837153           0.806105
# 11           0.777778           0.858134           0.826726
# 12           0.771690           0.857274           0.823154
# 13           0.781320           0.858116           0.826384
# 14           0.770106           0.844421           0.815421
# 15           0.776693           0.862798           0.830295
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.827617         0.818276        0.031757               11
# 1            0.839680         0.833025        0.030578                5
# 2            0.821363         0.815866        0.029730               15
# 3            0.840419         0.833884        0.029690                1
# 4            0.825545         0.816200        0.030378               13
# 5            0.841828         0.831113        0.027890                8
# 6            0.847010         0.814097        0.031747               16
# 7            0.844797         0.833289        0.027787                3
# 8            0.826678         0.818588        0.031556               10
# 9            0.836903         0.833716        0.028242                2
# 10           0.841230         0.815953        0.030928               14
# 11           0.840175         0.832512        0.029954                6
# 12           0.817061         0.823164        0.029670                9
# 13           0.839547         0.832489        0.028167                7
# 14           0.827145         0.817726        0.025554               12
# 15           0.839092         0.833042        0.030486                4

# %%
age_input = int(input("Enter the age: "))
bmi_input = float(input("Enter the BMI: "))
children_input = int(input("Enter the number of children: "))
sex_male_input = int(input("Enter 0 if you are male, 1 otherwise: "))
smoker_input = int(input("Enter 0 if you are a smoker, 1 otherwise: "))

# %%
# Create a DataFrame for the input data
input_data = pd.DataFrame({
    'age': [age_input],
    'bmi': [bmi_input],
    'children': [children_input],
    'sex_male': [sex_male_input],
    'smoker_yes': [smoker_input]
})

# %%
# Make predictions using the best model
predictions = GridSearchCV.predict(input_data)
print(f"Predicted insurance charges: {predictions}")
# Out:
# Predicted insurance charges: [44746.9047134]
