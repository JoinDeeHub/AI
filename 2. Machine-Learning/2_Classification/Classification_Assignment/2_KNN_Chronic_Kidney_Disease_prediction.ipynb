# %% [markdown]
# # Classification Assignment
# #### Problem Statement or Requirement:
#
# ###### A requirement from the Hospital, Management asked us to create a predictive model which will predict the Chronic Kidney Disease (CKD) based on the several parameters. The Client has provided the dataset of the same.
#
# ###### 1.) Identify your problem statement
#
# ###### 2.) Tell basic info about the dataset (Total number of rows, columns)
#
# ###### 3.) Mention the pre-processing method if you’re doing any (like converting string to number – nominal data)
#
# ###### 4.) Develop a good model with good evaluation metric. You can use any machine learning algorithm; you can create many models. Finally, you have to come up with final model.
#
# ###### 5.) All the research values of each algorithm should be documented. (You can make tabulation or screenshot of the results.)
#
# ###### 6.) Mention your final model, justify why u have chosen the same.

# %% [markdown]
# 1. The hospital wants a reliable predictive model to classify patients into CKD (Chronic Kidney Disease) or Not CKD, using medical attributes.
# You are tasked with building the best-performing classification model, evaluated using precision, recall, f1-score, and accuracy.
#
# Domain: ML
#
# Type: Supervised Learning
#
# Objective: Binary Classification

# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('CKD.csv')

# %% [markdown]
# 2. Tell basic info about the dataset (Total number of rows, columns)

# %%
print(f"\nRows: {dataset.shape[0]}")
print(f"\nColumns: {dataset.shape[1]}\n\n")

display(dataset)

# Displaying the dataset information
display(dataset.info())
# Out:
# Rows: 399
#
# Columns: 25
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             399 non-null    float64
#  1   bp              399 non-null    float64
#  2   sg              399 non-null    object
#  3   al              399 non-null    float64
#  4   su              399 non-null    float64
#  5   rbc             399 non-null    object
#  6   pc              399 non-null    object
#  7   pcc             399 non-null    object
#  8   ba              399 non-null    object
#  9   bgr             399 non-null    float64
#  10  bu              399 non-null    float64
#  11  sc              399 non-null    float64
#  12  sod             399 non-null    float64
#  13  pot             399 non-null    float64
#  14  hrmo            399 non-null    float64
#  15  pcv             399 non-null    float64
#  16  wc              399 non-null    float64
#  17  rc              399 non-null    float64
#  18  htn             399 non-null    object
#  19  dm              399 non-null    object
#  20  cad             399 non-null    object
#  21  appet           399 non-null    object
#  22  pe              399 non-null    object
#  23  ane             399 non-null    object
#  24  classification  399 non-null    object
# dtypes: float64(13), object(12)
# memory usage: 78.1+ KB
# None

# %% [markdown]
# 3.) Mention the pre-processing method if you’re doing any (like converting string to number – nominal data)

# %%
# Converting categorical variables to numerical
# as the classification column is categorical - ordinal data, will be converted to numerical values using LabelEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# Handle categorical and numerical separately
categorical_cols = dataset.select_dtypes(include='object').columns
numerical_cols = dataset.select_dtypes(exclude='object').columns

# Fill missing values
dataset[categorical_cols] = dataset[categorical_cols].fillna(dataset[categorical_cols].mode().iloc[0])
dataset[numerical_cols] = dataset[numerical_cols].fillna(dataset[numerical_cols].mean())

# Encode categorical columns
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    dataset[col] = le.fit_transform(dataset[col])
    label_encoders[col] = le

# %% [markdown]
# 4. Develop a good model with good evaluation metric. You can use any machine learning algorithm; you can create many models. Finally, you have to come up with final model.
#
# # K-Nearest_Neibour KNN

# %%
# Splitting the dataset into independent and dependent variables
independent = dataset.drop('classification', axis=1)
dependent = dataset['classification']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
StandardScaler = StandardScaler()
X_train = StandardScaler.fit_transform(X_train)
X_test = StandardScaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import GridSearchCV
# Setting up the parameter grid for KNN
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

# Creating the GridSearchCV object
grid = GridSearchCV(KNeighborsClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 

# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.909 total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.962 total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.944 total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=1.000 total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.981 total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.944 total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.909 total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.981 total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.962 total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=1.000 total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.854 total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.907 total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.963 total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.981 total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.873 total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.963 total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.907 total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.854 total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.981 total time=   0.0s[CV 2/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.963 total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.889 total time=   0.0s
#
# [CV 4/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.981 total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.981 total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.854 total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.854 total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.963 total time=   0.0s[CV 3/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.889 total time=   0.0s[CV 4/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.981 total time=   0.0s
#
#
# [CV 2/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.963 total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.907 total time=   0.0s[CV 2/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.963 total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.981 total time=   0.0s
#
# [CV 3/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.907 total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.981 total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.854 total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.854 total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.854 total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.981 total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.963 total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.926 total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.963 total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.981 total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.907 total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.909 total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.981 total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.981 total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.981 total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=1.000 total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.981 total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.926 total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.873 total time=   0.0s[CV 4/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.981 total time=   0.0s
#
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.981 total time=   0.0s[CV 5/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=1.000 total time=   0.0s
#
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.909 total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.873 total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.981 total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.926 total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.926 total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.889 total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.926 total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.981 total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.981 total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.981 total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.873 total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.891 total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.981 total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.981 total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.963 total time=   0.0s[CV 3/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.926 total time=   0.0s
#
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.981 total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.981 total time=   0.0s[CV 1/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.891 total time=   0.0s
#
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.926 total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.981 total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.981 total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.981 total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.981 total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.873 total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.963 total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.963 total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.926 total time=   0.0s
# [CV 5/5] END metric=minkowski, n_neighbors=3, weights=uniform;, score=1.000 total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.981 total time=   0.0s[CV 3/5] END metric=minkowski, n_neighbors=5, weights=uniform;, score=0.907 total time=   0.0s
#
# [CV 4/5] END metric=minkowski, n_neighbors=5, weights=uniform;, score=0.981 total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.926 total time=   0.0s[CV 5/5] END metric=minkowski, n_neighbors=5, weights=uniform;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=minkowski, n_neighbors=3, weights=distance;, score=0.909 total time=   0.0s[CV 1/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.873 total time=   0.0s
#
#
# [CV 1/5] END metric=minkowski, n_neighbors=5, weights=distance;, score=0.873 total time=   0.0s
# [CV 2/5] END metric=minkowski, n_neighbors=5, weights=distance;, score=0.963 total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.981 total time=   0.0s[CV 3/5] END metric=minkowski, n_neighbors=5, weights=distance;, score=0.907 total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.963 total time=   0.0s
# [CV 2/5] END metric=minkowski, n_neighbors=3, weights=distance;, score=0.962 total time=   0.0s
#
# [CV 4/5] END metric=minkowski, n_neighbors=5, weights=distance;, score=0.981 total time=   0.0s
# [CV 5/5] END metric=minkowski, n_neighbors=5, weights=distance;, score=0.981 total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.926 total time=   0.0s[CV 5/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=minkowski, n_neighbors=7, weights=uniform;, score=0.854 total time=   0.0s
# [CV 3/5] END metric=minkowski, n_neighbors=3, weights=distance;, score=0.944 total time=   0.0s
#
# [CV 2/5] END metric=minkowski, n_neighbors=7, weights=uniform;, score=0.963 total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.981 total time=   0.0s
# [CV 3/5] END metric=minkowski, n_neighbors=7, weights=uniform;, score=0.889 total time=   0.0s
# [CV 1/5] END metric=minkowski, n_neighbors=3, weights=uniform;, score=0.909 total time=   0.0s[CV 4/5] END metric=minkowski, n_neighbors=3, weights=distance;, score=0.981 total time=   0.0s
# [CV 4/5] END metric=minkowski, n_neighbors=7, weights=uniform;, score=0.981 total time=   0.0s
#
# [CV 5/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.981 total time=   0.0s
# [CV 5/5] END metric=minkowski, n_neighbors=7, weights=uniform;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=minkowski, n_neighbors=7, weights=distance;, score=0.854 total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.873 total time=   0.0s
# [CV 2/5] END metric=minkowski, n_neighbors=3, weights=uniform;, score=0.962 total time=   0.0s
# [CV 5/5] END metric=minkowski, n_neighbors=3, weights=distance;, score=1.000 total time=   0.0s[CV 2/5] END metric=minkowski, n_neighbors=7, weights=distance;, score=0.963 total time=   0.0s
#
# [CV 4/5] END metric=minkowski, n_neighbors=7, weights=distance;, score=0.981 total time=   0.0s
# [CV 3/5] END metric=minkowski, n_neighbors=7, weights=distance;, score=0.907 total time=   0.0s
# [CV 3/5] END metric=minkowski, n_neighbors=3, weights=uniform;, score=0.944 total time=   0.0s[CV 5/5] END metric=minkowski, n_neighbors=7, weights=distance;, score=0.981 total time=   0.0s
#
# [CV 1/5] END metric=minkowski, n_neighbors=5, weights=uniform;, score=0.854 total time=   0.0s
# [CV 2/5] END metric=minkowski, n_neighbors=9, weights=uniform;, score=0.963 total time=   0.0s
# [CV 1/5] END metric=minkowski, n_neighbors=9, weights=uniform;, score=0.854 total time=   0.0s[CV 3/5] END metric=minkowski, n_neighbors=9, weights=uniform;, score=0.889 total time=   0.0s
#
# [CV 2/5] END metric=minkowski, n_neighbors=5, weights=uniform;, score=0.963 total time=   0.0s
# [CV 4/5] END metric=minkowski, n_neighbors=9, weights=uniform;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=minkowski, n_neighbors=9, weights=distance;, score=0.854 total time=   0.0s
# [CV 4/5] END metric=minkowski, n_neighbors=3, weights=uniform;, score=0.981 total time=   0.0s[CV 2/5] END metric=minkowski, n_neighbors=9, weights=distance;, score=0.963 total time=   0.0s
#
# [CV 5/5] END metric=minkowski, n_neighbors=9, weights=uniform;, score=0.981 total time=   0.0s
# [CV 3/5] END metric=minkowski, n_neighbors=9, weights=distance;, score=0.907 total time=   0.0s
# [CV 4/5] END metric=minkowski, n_neighbors=9, weights=distance;, score=0.981 total time=   0.0s
# [CV 5/5] END metric=minkowski, n_neighbors=9, weights=distance;, score=0.981 total time=   0.0s
# [CV 4/5] END metric=minkowski, n_neighbors=11, weights=uniform;, score=0.981 total time=   0.0s
# [CV 1/5] END metric=minkowski, n_neighbors=11, weights=uniform;, score=0.854 total time=   0.0s
# [CV 2/5] END metric=minkowski, n_neighbors=11, weights=uniform;, score=0.963 total time=   0.0s
# [CV 5/5] END metric=minkowski, n_neighbors=11, weights=uniform;, score=0.981 total time=   0.0s
# [CV 3/5] END metric=minkowski, n_neighbors=11, weights=uniform;, score=0.889 total time=   0.0s
# [CV 1/5] END metric=minkowski, n_neighbors=11, weights=distance;, score=0.854 total time=   0.0s
# [CV 2/5] END metric=minkowski, n_neighbors=11, weights=distance;, score=0.963 total time=   0.0s
# [CV 3/5] END metric=minkowski, n_neighbors=11, weights=distance;, score=0.907 total time=   0.0s
# [CV 5/5] END metric=minkowski, n_neighbors=11, weights=distance;, score=0.981 total time=   0.0s
# [CV 4/5] END metric=minkowski, n_neighbors=11, weights=distance;, score=0.981 total time=   0.0s
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}: 0.9701163285572423

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[51  0]
#  [ 4 78]]

# %%
print("\nThe report using K-Nearest_Neibour KNN :\n\n\n",clf_report)
# Out:
# The report using K-Nearest_Neibour KNN :
#
#
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        51
#            1       1.00      0.95      0.97        82
#
#     accuracy                           0.97       133
#    macro avg       0.96      0.98      0.97       133
# weighted avg       0.97      0.97      0.97       133

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# np.float64(0.9990435198469632)

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.001616      0.000066         0.021359        0.005511    euclidean
# 1        0.002234      0.001369         0.011288        0.006327    euclidean
# 2        0.001583      0.000398         0.012275        0.002795    euclidean
# 3        0.001432      0.000100         0.013524        0.005635    euclidean
# 4        0.003150      0.002273         0.016084        0.004841    euclidean
# 5        0.001384      0.000323         0.005456        0.001752    euclidean
# 6        0.001336      0.000086         0.011042        0.004267    euclidean
# 7        0.001269      0.000108         0.004650        0.001349    euclidean
# 8        0.001923      0.001206         0.023180        0.014362    euclidean
# 9        0.001385      0.000371         0.003927        0.000112    euclidean
# 10       0.001251      0.000059         0.005753        0.002109    manhattan
# 11       0.001250      0.000041         0.005574        0.002171    manhattan
# 12       0.001330      0.000052         0.004002        0.000373    manhattan
# 13       0.001947      0.000972         0.008044        0.003430    manhattan
# 14       0.001881      0.001129         0.007237        0.003025    manhattan
# 15       0.001337      0.000043         0.004206        0.000106    manhattan
# 16       0.001831      0.000614         0.007419        0.003105    manhattan
# 17       0.001291      0.000042         0.008823        0.005794    manhattan
# 18       0.001539      0.000469         0.009971        0.002354    manhattan
# 19       0.002157      0.001003         0.010715        0.001989    manhattan
# 20       0.004755      0.001929         0.014525        0.003729    minkowski
# 21       0.004094      0.002505         0.012157        0.002091    minkowski
# 22       0.001846      0.000775         0.008193        0.005616    minkowski
# 23       0.001260      0.000151         0.003762        0.000212    minkowski
# 24       0.001333      0.000066         0.004027        0.000332    minkowski
# 25       0.002665      0.002135         0.004877        0.001282    minkowski
# 26       0.002259      0.001616         0.006745        0.003328    minkowski
# 27       0.001598      0.000426         0.005590        0.001118    minkowski
# 28       0.003694      0.002073         0.008376        0.004431    minkowski
# 29       0.001546      0.000255         0.007499        0.002542    minkowski
#
#     param_n_neighbors param_weights  \
# 0                   3       uniform
# 1                   3      distance
# 2                   5       uniform
# 3                   5      distance
# 4                   7       uniform
# 5                   7      distance
# 6                   9       uniform
# 7                   9      distance
# 8                  11       uniform
# 9                  11      distance
# 10                  3       uniform
# 11                  3      distance
# 12                  5       uniform
# 13                  5      distance
# 14                  7       uniform
# 15                  7      distance
# 16                  9       uniform
# 17                  9      distance
# 18                 11       uniform
# 19                 11      distance
# 20                  3       uniform
# 21                  3      distance
# 22                  5       uniform
# 23                  5      distance
# 24                  7       uniform
# 25                  7      distance
# 26                  9       uniform
# 27                  9      distance
# 28                 11       uniform
# 29                 11      distance
#
#                                                params  split0_test_score  \
# 0   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.908877
# 1   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.908877
# 2   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...           0.854321
# 3   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...           0.872586
# 4   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.854321
# 5   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.854321
# 6   {'metric': 'euclidean', 'n_neighbors': 9, 'wei...           0.854321
# 7   {'metric': 'euclidean', 'n_neighbors': 9, 'wei...           0.854321
# 8   {'metric': 'euclidean', 'n_neighbors': 11, 'we...           0.854321
# 9   {'metric': 'euclidean', 'n_neighbors': 11, 'we...           0.854321
# 10  {'metric': 'manhattan', 'n_neighbors': 3, 'wei...           0