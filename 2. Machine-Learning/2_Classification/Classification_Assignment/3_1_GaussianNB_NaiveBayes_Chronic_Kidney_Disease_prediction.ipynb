# %% [markdown]
# # Classification Assignment
# #### Problem Statement or Requirement:
#
# ###### A requirement from the Hospital, Management asked us to create a predictive model which will predict the Chronic Kidney Disease (CKD) based on the several parameters. The Client has provided the dataset of the same.

# %% [markdown]
# 1. The hospital wants a reliable predictive model to classify patients into CKD (Chronic Kidney Disease) or Not CKD, using medical attributes.
# You are tasked with building the best-performing classification model, evaluated using precision, recall, f1-score, and accuracy.
#
# Domain: ML
#
# Type: Supervised Learning
#
# Objective: Binary Classification

# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB, ComplementNB, CategoricalNB
from sklearn.metrics import classification_report, accuracy_score

# %%
# Reading the Dataset
dataset = pd.read_csv('CKD.csv')

# %% [markdown]
# 2. Tell basic info about the dataset (Total number of rows, columns)

# %%
print(f"\nRows: {dataset.shape[0]}")
print(f"\nColumns: {dataset.shape[1]}\n\n")

display(dataset)

# Displaying the dataset information
display(dataset.info())
# Out:
# Rows: 399
#
# Columns: 25
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             399 non-null    float64
#  1   bp              399 non-null    float64
#  2   sg              399 non-null    object
#  3   al              399 non-null    float64
#  4   su              399 non-null    float64
#  5   rbc             399 non-null    object
#  6   pc              399 non-null    object
#  7   pcc             399 non-null    object
#  8   ba              399 non-null    object
#  9   bgr             399 non-null    float64
#  10  bu              399 non-null    float64
#  11  sc              399 non-null    float64
#  12  sod             399 non-null    float64
#  13  pot             399 non-null    float64
#  14  hrmo            399 non-null    float64
#  15  pcv             399 non-null    float64
#  16  wc              399 non-null    float64
#  17  rc              399 non-null    float64
#  18  htn             399 non-null    object
#  19  dm              399 non-null    object
#  20  cad             399 non-null    object
#  21  appet           399 non-null    object
#  22  pe              399 non-null    object
#  23  ane             399 non-null    object
#  24  classification  399 non-null    object
# dtypes: float64(13), object(12)
# memory usage: 78.1+ KB
# None

# %% [markdown]
# 3.) Mention the pre-processing method if you’re doing any (like converting string to number – nominal data)

# %%
# Converting categorical variables to numerical
# as the classification column is categorical - ordinal data, will be converted to numerical values using LabelEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# Handle categorical and numerical separately
categorical_cols = dataset.select_dtypes(include='object').columns
numerical_cols = dataset.select_dtypes(exclude='object').columns

# Fill missing values
dataset[categorical_cols] = dataset[categorical_cols].fillna(dataset[categorical_cols].mode().iloc[0])
dataset[numerical_cols] = dataset[numerical_cols].fillna(dataset[numerical_cols].mean())

# Encode categorical columns
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    dataset[col] = le.fit_transform(dataset[col])
    label_encoders[col] = le

# %% [markdown]
# 4. Develop a good model with good evaluation metric. You can use any machine learning algorithm; you can create many models. Finally, you have to come up with final model.
#
# # NaiveBayes

# %%
# Splitting the dataset into independent and dependent variables
independent = dataset.drop('classification', axis=1)
dependent = dataset['classification']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
StandardScaler = StandardScaler()
X_train = StandardScaler.fit_transform(X_train)
X_test = StandardScaler.transform(X_test)

# %% [markdown]
# # GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'var_smoothing': np.logspace(0,-9, num=100)}


grid = GridSearchCV(GaussianNB(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted')

# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 2/5] END .................var_smoothing=1.0;, score=0.833 total time=   0.0s
# [CV 1/5] END .................var_smoothing=1.0;, score=0.741 total time=   0.0s
# [CV 5/5] END .................var_smoothing=1.0;, score=0.907 total time=   0.0s
# [CV 1/5] END ..var_smoothing=0.8111308307896871;, score=0.741 total time=   0.0s
# [CV 2/5] END ..var_smoothing=0.8111308307896871;, score=0.833 total time=   0.0s
# [CV 3/5] END ..var_smoothing=0.8111308307896871;, score=0.714 total time=   0.0s
# [CV 4/5] END ..var_smoothing=0.8111308307896871;, score=0.851 total time=   0.0s
# [CV 5/5] END ..var_smoothing=0.8111308307896871;, score=0.907 total time=   0.0s
# [CV 1/5] END ...var_smoothing=0.657933224657568;, score=0.741 total time=   0.0s
# [CV 2/5] END ...var_smoothing=0.657933224657568;, score=0.871 total time=   0.0s
# [CV 3/5] END ...var_smoothing=0.657933224657568;, score=0.755 total time=   0.0s
# [CV 4/5] END ...var_smoothing=0.657933224657568;, score=0.870 total time=   0.0s
# [CV 5/5] END ...var_smoothing=0.657933224657568;, score=0.907 total time=   0.0s
# [CV 2/5] END ...var_smoothing=0.533669923120631;, score=0.907 total time=   0.0s
# [CV 3/5] END ...var_smoothing=0.533669923120631;, score=0.794 total time=   0.0s
# [CV 4/5] END ...var_smoothing=0.533669923120631;, score=0.889 total time=   0.0s
# [CV 1/5] END ...var_smoothing=0.533669923120631;, score=0.760 total time=   0.0s[CV 5/5] END ...var_smoothing=0.533669923120631;, score=0.926 total time=   0.0s
#
# [CV 1/5] END .var_smoothing=0.43287612810830584;, score=0.780 total time=   0.0s
# [CV 3/5] END .var_smoothing=0.43287612810830584;, score=0.813 total time=   0.0s
# [CV 4/5] END .var_smoothing=0.43287612810830584;, score=0.889 total time=   0.0s
# [CV 2/5] END .var_smoothing=0.43287612810830584;, score=0.907 total time=   0.0s
# [CV 5/5] END .var_smoothing=0.43287612810830584;, score=0.944 total time=   0.0s
# [CV 2/5] END ..var_smoothing=0.3511191734215131;, score=0.926 total time=   0.0s
# [CV 3/5] END ..var_smoothing=0.3511191734215131;, score=0.870 total time=   0.0s
# [CV 4/5] END ..var_smoothing=0.3511191734215131;, score=0.907 total time=   0.0s
# [CV 1/5] END ..var_smoothing=0.3511191734215131;, score=0.817 total time=   0.0s
# [CV 5/5] END ..var_smoothing=0.3511191734215131;, score=0.963 total time=   0.0s
# [CV 1/5] END ..var_smoothing=0.2848035868435802;, score=0.854 total time=   0.0s
# [CV 3/5] END ..var_smoothing=0.2848035868435802;, score=0.870 total time=   0.0s
# [CV 4/5] END ..var_smoothing=0.2848035868435802;, score=0.944 total time=   0.0s
# [CV 2/5] END ..var_smoothing=0.2848035868435802;, score=0.944 total time=   0.0s
# [CV 5/5] END ..var_smoothing=0.2848035868435802;, score=0.963 total time=   0.0s[CV 2/5] END .var_smoothing=0.23101297000831597;, score=0.925 total time=   0.0s
#
# [CV 1/5] END .var_smoothing=0.23101297000831597;, score=0.854 total time=   0.0s[CV 3/5] END .var_smoothing=0.23101297000831597;, score=0.889 total time=   0.0s
#
# [CV 4/5] END .var_smoothing=0.23101297000831597;, score=0.944 total time=   0.0s[CV 1/5] END ..var_smoothing=0.1873817422860384;, score=0.873 total time=   0.0s
#
# [CV 2/5] END ..var_smoothing=0.1873817422860384;, score=0.925 total time=   0.0s
# [CV 5/5] END .var_smoothing=0.23101297000831597;, score=0.981 total time=   0.0s
# [CV 3/5] END ..var_smoothing=0.1873817422860384;, score=0.907 total time=   0.0s
# [CV 5/5] END ..var_smoothing=0.1873817422860384;, score=0.981 total time=   0.0s
# [CV 1/5] END .var_smoothing=0.15199110829529336;, score=0.873 total time=   0.0s
# [CV 4/5] END ..var_smoothing=0.1873817422860384;, score=0.963 total time=   0.0s
# [CV 2/5] END .var_smoothing=0.15199110829529336;, score=0.944 total time=   0.0s
# [CV 4/5] END .var_smoothing=0.15199110829529336;, score=0.963 total time=   0.0s
# [CV 3/5] END .var_smoothing=0.15199110829529336;, score=0.907 total time=   0.0s
# [CV 5/5] END .var_smoothing=0.15199110829529336;, score=0.981 total time=   0.0s
# [CV 3/5] END .var_smoothing=0.12328467394420659;, score=0.926 total time=   0.0s
# [CV 4/5] END .var_smoothing=0.12328467394420659;, score=0.981 total time=   0.0s
# [CV 5/5] END .var_smoothing=0.12328467394420659;, score=0.981 total time=   0.0s
# [CV 1/5] END .var_smoothing=0.12328467394420659;, score=0.873 total time=   0.0s
# [CV 1/5] END .................var_smoothing=0.1;, score=0.873 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.1;, score=0.944 total time=   0.0s
# [CV 2/5] END .var_smoothing=0.12328467394420659;, score=0.944 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.1;, score=0.926 total time=   0.0s
# [CV 1/5] END .var_smoothing=0.08111308307896872;, score=0.873 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.1;, score=0.981 total time=   0.0s
# [CV 2/5] END .var_smoothing=0.08111308307896872;, score=0.944 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.1;, score=0.981 total time=   0.0s
# [CV 3/5] END .var_smoothing=0.08111308307896872;, score=0.944 total time=   0.0s
# [CV 5/5] END .var_smoothing=0.08111308307896872;, score=0.981 total time=   0.0s
# [CV 4/5] END .var_smoothing=0.08111308307896872;, score=0.981 total time=   0.0s
# [CV 1/5] END ..var_smoothing=0.0657933224657568;, score=0.873 total time=   0.0s
# [CV 4/5] END ..var_smoothing=0.0657933224657568;, score=0.981 total time=   0.0s
# [CV 2/5] END ..var_smoothing=0.0657933224657568;, score=0.944 total time=   0.0s
# [CV 5/5] END ..var_smoothing=0.0657933224657568;, score=0.981 total time=   0.0s
# [CV 3/5] END ..var_smoothing=0.0657933224657568;, score=0.944 total time=   0.0s
# [CV 1/5] END ..var_smoothing=0.0533669923120631;, score=0.891 total time=   0.0s
# [CV 2/5] END ..var_smoothing=0.0533669923120631;, score=0.944 total time=   0.0s
# [CV 3/5] END ..var_smoothing=0.0533669923120631;, score=0.944 total time=   0.0s
# [CV 2/5] END .var_smoothing=0
, score=0.944 total time=   0.0s
# [CV 3/5] END var_smoothing=8.111308307896872e-05;, score=0.944 total time=   0.0s
# [CV 4/5] END var_smoothing=4.328761281083062e-05;, score=1.000 total time=   0.0s
# [CV 5/5] END var_smoothing=4.328761281083062e-05;, score=0.981 total time=   0.0s
# [CV 3/5] END var_smoothing=2.848035868435799e-05;, score=0.944 total time=   0.0s
# [CV 1/5] END var_smoothing=6.579332246575683e-05;, score=0.909 total time=   0.0s
# [CV 1/5] END var_smoothing=3.511191734215127e-05;, score=0.909 total time=   0.0s
# [CV 4/5] END var_smoothing=2.848035868435799e-05;, score=1.000 total time=   0.0s
# [CV 3/5] END .................var_smoothing=1.0;, score=0.714 total time=   0.0s
# [CV 2/5] END var_smoothing=3.511191734215127e-05;, score=0.962 total time=   0.0s
# [CV 5/5] END var_smoothing=2.848035868435799e-05;, score=0.981 total time=   0.0s
# [CV 3/5] END var_smoothing=3.511191734215127e-05;, score=0.944 total time=   0.0s[CV 2/5] END var_smoothing=6.579332246575683e-05;, score=0.962 total time=   0.0s
#
# [CV 1/5] END var_smoothing=2.310129700083158e-05;, score=0.909 total time=   0.0s
# [CV 4/5] END var_smoothing=3.511191734215127e-05;, score=1.000 total time=   0.0s
# [CV 2/5] END var_smoothing=2.310129700083158e-05;, score=0.962 total time=   0.0s
# [CV 3/5] END var_smoothing=2.310129700083158e-05;, score=0.944 total time=   0.0s[CV 5/5] END var_smoothing=3.511191734215127e-05;, score=0.981 total time=   0.0s
#
# [CV 4/5] END var_smoothing=2.310129700083158e-05;, score=1.000 total time=   0.0s
# [CV 1/5] END var_smoothing=2.848035868435799e-05;, score=0.909 total time=   0.0s
# [CV 3/5] END var_smoothing=6.579332246575683e-05;, score=0.944 total time=   0.0s
# [CV 5/5] END var_smoothing=2.310129700083158e-05;, score=0.981 total time=   0.0s
# [CV 2/5] END var_smoothing=2.848035868435799e-05;, score=0.962 total time=   0.0s
# [CV 1/5] END var_smoothing=1.873817422860383e-05;, score=0.909 total time=   0.0s
# [CV 2/5] END var_smoothing=1.873817422860383e-05;, score=0.962 total time=   0.0s
# [CV 4/5] END var_smoothing=6.579332246575683e-05;, score=1.000 total time=   0.0s
# [CV 3/5] END var_smoothing=1.873817422860383e-05;, score=0.944 total time=   0.0s
# [CV 4/5] END var_smoothing=1.5199110829529332e-05;, score=1.000 total time=   0.0s
# [CV 4/5] END var_smoothing=1.873817422860383e-05;, score=1.000 total time=   0.0s
# [CV 5/5] END var_smoothing=1.5199110829529332e-05;, score=0.981 total time=   0.0s
# [CV 5/5] END var_smoothing=1.873817422860383e-05;, score=0.981 total time=   0.0s
# [CV 1/5] END var_smoothing=1.2328467394420658e-05;, score=0.909 total time=   0.0s
# [CV 1/5] END var_smoothing=1.5199110829529332e-05;, score=0.909 total time=   0.0s
# [CV 5/5] END var_smoothing=6.579332246575683e-05;, score=0.981 total time=   0.0s
# [CV 2/5] END var_smoothing=1.2328467394420658e-05;, score=0.962 total time=   0.0s
# [CV 2/5] END var_smoothing=1.5199110829529332e-05;, score=0.962 total time=   0.0s
# [CV 3/5] END var_smoothing=1.2328467394420658e-05;, score=0.944 total time=   0.0s
# [CV 3/5] END var_smoothing=1.5199110829529332e-05;, score=0.944 total time=   0.0s
# [CV 4/5] END var_smoothing=1.2328467394420658e-05;, score=1.000 total time=   0.0s
# [CV 5/5] END var_smoothing=1.2328467394420658e-05;, score=0.981 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-05;, score=0.962 total time=   0.0s[CV 1/5] END ...............var_smoothing=1e-05;, score=0.909 total time=   0.0s
#
# [CV 1/5] END var_smoothing=5.3366992312063123e-05;, score=0.909 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-05;, score=0.944 total time=   0.0s
# [CV 5/5] END var_smoothing=8.111308307896873e-06;, score=0.981 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-05;, score=1.000 total time=   0.0s
# [CV 1/5] END var_smoothing=6.579332246575683e-06;, score=0.909 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-05;, score=0.981 total time=   0.0s
# [CV 2/5] END var_smoothing=6.579332246575683e-06;, score=0.962 total time=   0.0s
# [CV 3/5] END var_smoothing=6.579332246575683e-06;, score=0.944 total time=   0.0s
# [CV 1/5] END var_smoothing=8.111308307896873e-06;, score=0.909 total time=   0.0s
# [CV 3/5] END var_smoothing=5.336699231206313e-06;, score=0.944 total time=   0.0s
# [CV 4/5] END var_smoothing=6.579332246575683e-06;, score=1.000 total time=   0.0s
# [CV 2/5] END var_smoothing=8.111308307896873e-06;, score=0.962 total time=   0.0s
# [CV 5/5] END var_smoothing=6.579332246575683e-06;, score=0.981 total time=   0.0s
# [CV 3/5] END var_smoothing=8.111308307896873e-06;, score=0.944 total time=   0.0s
# [CV 1/5] END var_smoothing=5.336699231206313e-06;, score=0.909 total time=   0.0s
# [CV 2/5] END var_smoothing=5.336699231206313e-06;, score=0.962 total time=   0.0s
# [CV 4/5] END var_smoothing=8.111308307896873e-06;, score=1.000 total time=   0.0s
# [CV 4/5] END var_smoothing=5.336699231206313e-06;, score=1.000 total time=   0.0s
# [CV 1/5] END var_smoothing=3.5111917342151275e-06;, score=0.909 total time=   0.0s
# [CV 5/5] END var_smoothing=5.336699231206313e-06;, score=0.981 total time=   0.0s
# [CV 2/5] END var_smoothing=3.5111917342151275e-06;, score=0.962 total time=   0.0s
# [CV 3/5] END var_smoothing=3.5111917342151275e-06;, score=0.944 total time=   0.0s
# [CV 2/5] END var_smoothing=1.873817422860383e-06;, score=0.962 total time=   0.0s
# [CV 1/5] END var_smoothing=4.328761281083053e-06;, score=0.909 total time=   0.0s
# [CV 4/5] END var_smoothing=3.5111917342151275e-06;, score=1.000 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-06;, score=0.944 total time=   0.0s
# [CV 5/5] END var_smoothing=3.5111917342151275e-06;, score=0.981 total time=   0.0s
# [CV 1/5] END var_smoothing=2.848035868435799e-06;, score=0.909 total time=   0.0s[CV 3/5] END var_smoothing=1.873817422860383e-06;, score=0.944 total time=   0.0s
#
# [CV 2/5] END var_smoothing=2.848035868435799e-06;, score=0.962 total time=   0.0s
# [CV 4/5] END var_smoothing=1.873817422860383e-06;, score=1.000 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-06;, score=1.000 total time=   0.0s
# [CV 3/5] END var_smoothing=2.848035868435799e-06;, score=0.944 total time=   0.0s
# [CV 2/5] END var_smoothing=4.328761281083053e-06;, score=0.962 total time=   0.0s
# [CV 5/5] END var_smoothing=1.873817422860383e-06;, score=0.981 total time=   0.0s
# [CV 4/5] END var_smoothing=2.848035868435799e-06;, score=1.000 total time=   0.0s
# [CV 1/5] END var_smoothing=1.519911082952933e-06;, score=0.909 total time=   0.0s
# [CV 5/5] END var_smoothing=2.848035868435799e-06;, score=0.981 total time=   0.0s
# [CV 2/5] END var_smoothing=1.519911082952933e-06;, score=0.962 total time=   0.0s
# [CV 1/5] END var_smoothing=2.310129700083158e-06;, score=0.909 total time=   0.0s
# [CV 2/5] END var_smoothing=2.310129700083158e-06;, score=0.962 total time=   0.0s[CV 3/5] END var_smoothing=1.519911082952933e-06;, score=0.944 total time=   0.0s
#
# [CV 3/5] END var_smoothing=4.328761281083053e-06;, score=0.944 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-06;, score=0.981 total time=   0.0s
# [CV 4/5] END var_smoothing=1.519911082952933e-06;, score=1.000 total time=   0.0s[CV 3/5] END var_smoothing=2.310129700083158e-06;, score=0.944 total time=   0.0s
#
# [CV 4/5] END var_smoothing=2.310129700083158e-06;, score=1.000 total time=   0.0s
# [CV 5/5] END var_smoothing=1.519911082952933e-06;, score=0.981 total time=   0.0s
# [CV 1/5] END var_smoothing=8.111308307896872e-07;, score=0.909 total time=   0.0s
# [CV 5/5] END var_smoothing=2.310129700083158e-06;, score=0.981 total time=   0.0s
# [CV 4/5] END var_smoothing=4.328761281083053e-06;, score=1.000 total time=   0.0s
# [CV 1/5] END var_smoothing=1.232846739442066e-06;, score=0.909 total time=   0.0s
# [CV 1/5] END var_smoothing=1.873817422860383e-06;, score=0.909 total time=   0.0s
# [CV 2/5] END var_smoothing=1.232846739442066e-06;, score=0.962 total time=   0.0s
# [CV 4/5] END var_smoothing=5.336699231206313e-07;, score=1.000 total time=   0.0s
# [CV 3/5] END var_smoothing=1.232846739442066e-06;, score=0.944 total time=   0.0s
# [CV 2/5] END var_smoothing=8.111308307896872e-07;, score=0.962 total time=   0.0s
# [CV 5/5] END var_smoothing=5.336699231206313e-07;, score=0.981 total time=   0.0s
# [CV 5/5] END var_smoothing=4.328761281083053e-06;, score=0.981 total time=   0.0s
# [CV 1/5] END var_smoothing=4.3287612810830526e-07;, score=0.909 total time=   0.0s
# [CV 3/5] END var_smoothing=8.111308307896872e-07;, score=0.944 total time=   0.0s
# [CV 4/5] END var_smoothing=1.232846739442066e-06;, score=1.000 total time=   0.0s
# [CV 2/5] END var_smoothing=4.3287612810830526e-07;, score=0.962 total time=   0.0s
# [CV 3/5] END var_smoothing=4.3287612810830526e-07;, score=0.944 total time=   0.0s
# [CV 5/5] END var_smoothing=2.848035868435799e-07;, score=0.981 total time=   0.0s
# [CV 5/5] END var_smoothing=1.232846739442066e-06;, score=0.981 total time=   0.0s
# [CV 4/5] END var_smoothing=4.3287612810830526e-07;, score=1.000 total time=   0.0s
# [CV 4/5] END var_smoothing=8.111308307896872e-07;, score=1.000 total time=   0.0s
# [CV 5/5] END var_smoothing=4.3287612810830526e-07;, score=0.981 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-06;, score=0.909 total time=   0.0s
# [CV 1/5] END var_smoothing=2.310129700083158e-07;, score=0.909 total time=   0.0s
# [CV 1/5] END var_smoothing=3.5111917342151277e-07;, score=0.909 total time=   0.0s
# [CV 5/5] END var_smoothing=8.111308307896872e-07;, score=0.981 total time=   0.0s[CV 2/5] END ...............var_smoothing=1e-06;, score=0.962 total time=   0.0s[CV 2/5] END var_smoothing=3.5111917342151277e-07;, score=0.962 total time=   0.0s
#
# [CV 3/5] END var_smoothing=3.5111917342151277e-07;, score=0.944 total time=   0.0s
#
# [CV 4/5] END var_smoothing=3.5111917342151277e-07;, score=1.000 total time=   0.0s
# [CV 2/5] END var_smoothing=2.310129700083158e-07;, score=0.962 total time=   0.0s[CV 1/5] END var_smoothing=1.232846739442066e-07;, score=0.909 total time=   0.0s
#
# [CV 5/5] END var_smoothing=3.5111917342151277e-07;, score=0.981 total time=   0.0s
# [CV 2/5] END var_smoothing=1.232846739442066e-07;, score=0.962 total time=   0.0s
# [CV 1/5] END var_smoothing=6.579332246575682e-07;, score=0.909 total time=   0.0s
# [CV 1/5] END var_smoothing=2.848035868435799e-07;, score=0.909 total time=   0.0s
# [CV 3/5] END var_smoothing=2.310129700083158e-07;, score=0.944 total time=   0.0s
# [CV 3/5] END var_smoothing=1.232846739442066e-07;, score=0.944 total time=   0.0s
# [CV 2/5] END var_smoothing=2.848035868435799e-07;, score=0.962 total time=   0.0s
# [CV 4/5] END var_smoothing=1.232846739442066e-07;, score=1.000 total time=   0.0s
# [CV 3/5] END var_smoothing=2.848035868435799e-07;, score=0.944 total time=   0.0s
# [CV 4/5] END var_smoothing=2.848035868435799e-07;, score=1.000 total time=   0.0s
# [CV 2/5] END var_smoothing=6.579332246575682e-07;, score=0.962 total time=   0.0s[CV 5/5] END var_smoothing=1.232846739442066e-07;, score=0.981 total time=   0.0s
#
# [CV 4/5] END var_smoothing=2.310129700083158e-07;, score=1.000 total time=   0.0s[CV 1/5] END ...............var_smoothing=1e-07;, score=0.909 total time=   0.0s
# [CV 2/5] END var_smoothing=6.579332246575682e-08;, score=0.962 total time=   0.0s
#
# [CV 3/5] END var_smoothing=6.579332246575682e-08;, score=0.944 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-07;, score=0.962 total time=   0.0s
# [CV 3/5] END var_smoothing=6.579332246575682e-07;, score=0.944 total time=   0.0s
# [CV 4/5] END var_smoothing=6.579332246575682e-08;, score=1.000 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-07;, score=0.944 total time=   0.0s
# [CV 5/5] END var_smoothing=2.310129700083158e-07;, score=0.981 total time=   0.0s
# [CV 5/5] END var_smoothing=6.579332246575682e-08;, score=0.981 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-07;, score=1.000 total time=   0.0s
# [CV 1/5] END var_smoothing=5.336699231206302e-08;, score=0.909 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-07;, score=0.981 total time=   0.0s
# [CV 1/5] END var_smoothing=1.873817422860383e-07;, score=0.909 total time=   0.0s
# [CV 2/5] END var_smoothing=5.336699231206302e-08;, score=0.962 total time=   0.0s
# [CV 1/5] END var_smoothing=8.111308307896873e-08;, score=0.909 total time=   0.0s[CV 3/5] END var_smoothing=5.336699231206302e-08;, score=0.944 total time=   0.0s
#
# [CV 4/5] END var_smoothing=6.579332246575682e-07;, score=1.000 total time=   0.0s
# [CV 4/5] END var_smoothing=5.336699231206302e-08;, score=1.000 total time=   0.0s
# [CV 2/5] END var_smoothing=8.111308307896873e-08;, score=0.962 total time=   0.0s
# [CV 2/5] END var_smoothing=1.873817422860383e-07;, score=0.962 total time=   0.0s
# [CV 5/5] END var_smoothing=5.336699231206302e-08;, score=0.981 total time=   0.0s
# [CV 3/5] END var_smoothing=8.111308307896873e-08;, score=0.944 total time=   0.0s
# [CV 1/5] END var_smoothing=4.3287612810830526e-08;, score=0.909 total time=   0.0s
# [CV 5/5] END var_smoothing=6.579332246575682e-07;, score=0.981 total time=   0.0s
# [CV 4/5] END var_smoothing=8.111308307896873e-08;, score=1.000 total time=   0.0s
# [CV 2/5] END var_smoothing=4.3287612810830526e-08;, score=0.962 total time=   0.0s
# [CV 3/5] END var_smoothing=1.873817422860383e-07;, score=0.944 total time=   0.0s
# [CV 3/5] END var_smoothing=4.3287612810830526e-08;, score=0.944 total time=   0.0s
# [CV 5/5] END var_smoothing=8.111308307896873e-08;, score=0.981 total time=   0.0s
# [CV 4/5] END var_smoothing=1.873817422860383e-07;, score=1.000 total time=   0.0s
# [CV 4/5] END var_smoothing=4.3287612810830526e-08;, score=1.000 total time=   0.0s
# [CV 1/5] END var_smoothing=6.579332246575682e-08;, score=0.909 total time=   0.0s[CV 1/5] END var_smoothing=5.336699231206313e-07;, score=0.909 total time=   0.0s
#
# [CV 5/5] END var_smoothing=4.3287612810830526e-08;, score=0.981 total time=   0.0s
# [CV 1/5] END var_smoothing=3.5111917342151277e-08;, score=0.909 total time=   0.0s
# [CV 2/5] END var_smoothing=5.336699231206313e-07;, score=0.962 total time=   0.0s[CV 3/5] END var_smoothing=3.5111917342151277e-08;, score=0.944 total time=   0.0s
#
# [CV 2/5] END var_smoothing=3.5111917342151277e-08;, score=0.962 total time=   0.0s
# [CV 5/5] END var_smoothing=1.873817422860383e-07;, score=0.981 total time=   0.0s
# [CV 4/5] END var_smoothing=3.5111917342151277e-08;, score=1.000 total time=   0.0s
# [CV 4/5] END var_smoothing=1.873817422860383e-08;, score=1.000 total time=   0.0s
# [CV 3/5] END var_smoothing=5.336699231206313e-07;, score=0.944 total time=   0.0s
# [CV 1/5] END var_smoothing=1.519911082952933e-07;, score=0.909 total time=   0.0s
# [CV 5/5] END var_smoothing=1.873817422860383e-08;, score=0.981 total time=   0.0s
# [CV 5/5] END var_smoothing=3.5111917342151277e-08;, score=0.981 total time=   0.0s
# [CV 2/5] END var_smoothing=1.519911082952933e-07;, score=0.962 total time=   0.0s
# [CV 2/5] END var_smoothing=1.519911082952933e-08;, score=0.962 total time=   0.0s
# [CV 1/5] END var_smoothing=1.519911082952933e-08;, score=0.909 total time=   0.0s
# [CV 3/5] END var_smoothing=1.519911082952933e-08;, score=0.944 total time=   0.0s
# [CV 1/5] END var_smoothing=2.848035868435799e-08;, score=0.909 total time=   0.0s
# [CV 3/5] END var_smoothing=1.519911082952933e-07;, score=0.944 total time=   0.0s
# [CV 2/5] END var_smoothing=2.848035868435799e-08;, score=0.962 total time=   0.0s
# [CV 4/5] END var_smoothing=1.519911082952933e-07;, score=1.000 total time=   0.0s[CV 4/5] END var_smoothing=1.519911082952933e-08;, score=1.000 total time=   0.0s
# [CV 3/5] END var_smoothing=2.848035868435799e-08;, score=0.944 total time=   0.0s
#
# [CV 5/5] END var_smoothing=1.519911082952933e-08;, score=0.981 total time=   0.0s
# [CV 4/5] END var_smoothing=2.848035868435799e-08;, score=1.000 total time=   0.0s
# [CV 5/5] END var_smoothing=2.848035868435799e-08;, score=0.981 total time=   0.0s
# [CV 5/5] END var_smoothing=1.519911082952933e-07;, score=0.981 total time=   0.0s
# [CV 1/5] END var_smoothing=1.232846739442066e-08;, score=0.909 total time=   0.0s[CV 1/5] END var_smoothing=2.310129700083158e-08;, score=0.909 total time=   0.0s
#
# [CV 2/5] END var_smoothing=1.232846739442066e-08;, score=0.962 total time=   0.0s
# [CV 2/5] END var_smoothing=2.310129700083158e-08;, score=0.962 total time=   0.0s
# [CV 3/5] END var_smoothing=2.310129700083158e-08;, score=0.944 total time=   0.0s
# [CV 4/5] END var_smoothing=2.310129700083158e-08;, score=1.000 total time=   0.0s
# [CV 4/5] END var_smoothing=1.232846739442066e-08;, score=1.000 total time=   0.0s[CV 5/5] END var_smoothing=2.310129700083158e-08;, score=0.981 total time=   0.0s
#
# [CV 5/5] END var_smoothing=1.232846739442066e-08;, score=0.981 total time=   0.0s
# [CV 1/5] END var_smoothing=1.873817422860383e-08;, score=0.909 total time=   0.0s
# [CV 3/5] END var_smoothing=1.232846739442066e-08;, score=0.944 total time=   0.0s
# [CV 2/5] END var_smoothing=1.873817422860383e-08;, score=0.962 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-08;, score=0.909 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-08;, score=0.962 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-08;, score=0.944 total time=   0.0s
# [CV 3/5] END var_smoothing=1.873817422860383e-08;, score=0.944 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-08;, score=0.981 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-08;, score=1.000 total time=   0.0s
# [CV 1/5] END var_smoothing=8.111308307896856e-09;, score=0.909 total time=   0.0s
# [CV 3/5] END var_smoothing=8.111308307896856e-09;, score=0.944 total time=   0.0s
# [CV 2/5] END var_smoothing=8.111308307896856e-09;, score=0.962 total time=   0.0s[CV 5/5] END var_smoothing=8.111308307896856e-09;, score=0.981 total time=   0.0s
# [CV 4/5] END var_smoothing=8.111308307896856e-09;, score=1.000 total time=   0.0s
#
# [CV 3/5] END var_smoothing=6.579332246575682e-09;, score=0.944 total time=   0.0s
# [CV 2/5] END var_smoothing=6.579332246575682e-09;, score=0.962 total time=   0.0s[CV 1/5] END var_smoothing=6.579332246575682e-09;, score=0.909 total time=   0.0s
# [CV 4/5] END var_smoothing=6.579332246575682e-09;, score=1.000 total time=   0.0s
#
# [CV 1/5] END var_smoothing=5.336699231206302e-09;, score=0.909 total time=   0.0s
# [CV 5/5] END var_smoothing=6.579332246575682e-09;, score=0.981 total time=   0.0s
# [CV 2/5] END var_smoothing=5.336699231206302e-09;, score=0.962 total time=   0.0s
# [CV 3/5] END var_smoothing=5.336699231206302e-09;, score=0.944 total time=   0.0s
# [CV 1/5] END var_smoothing=4.328761281083061e-09;, score=0.909 total time=   0.0s[CV 4/5] END var_smoothing=5.336699231206302e-09;, score=1.000 total time=   0.0s
#
# [CV 5/5] END var_smoothing=5.336699231206302e-09;, score=0.981 total time=   0.0s
# [CV 4/5] END var_smoothing=4.328761281083061e-09;, score=1.000 total time=   0.0s[CV 2/5] END var_smoothing=4.328761281083061e-09;, score=0.962 total time=   0.0s
#
# [CV 3/5] END var_smoothing=4.328761281083061e-09;, score=0.944 total time=   0.0s
# [CV 1/5] END var_smoothing=3.5111917342151273e-09;, score=0.909 total time=   0.0s
# [CV 2/5] END var_smoothing=3.5111917342151273e-09;, score=0.962 total time=   0.0s
# [CV 4/5] END var_smoothing=3.5111917342151273e-09;, score=1.000 total time=   0.0s
# [CV 5/5] END var_smoothing=4.328761281083061e-09;, score=0.981 total time=   0.0s
# [CV 1/5] END var_smoothing=2.848035868435805e-09;, score=0.909 total time=   0.0s[CV 5/5] END var_smoothing=3.5111917342151273e-09;, score=0.981 total time=   0.0s
#
# [CV 2/5] END var_smoothing=2.848035868435805e-09;, score=0.962 total time=   0.0s
# [CV 3/5] END var_smoothing=3.5111917342151273e-09;, score=0.944 total time=   0.0s
# [CV 3/5] END var_smoothing=2.848035868435805e-09;, score=0.944 total time=   0.0s
# [CV 1/5] END var_smoothing=2.310129700083158e-09;, score=0.909 total time=   0.0s
# [CV 4/5] END var_smoothing=2.848035868435805e-09;, score=1.000 total time=   0.0s
# [CV 2/5] END var_smoothing=2.310129700083158e-09;, score=0.962 total time=   0.0s
# [CV 5/5] END var_smoothing=2.848035868435805e-09;, score=0.981 total time=   0.0s
# [CV 4/5] END var_smoothing=2.310129700083158e-09;, score=1.000 total time=   0.0s
# [CV 3/5] END var_smoothing=2.310129700083158e-09;, score=0.944 total time=   0.0s
# [CV 5/5] END var_smoothing=2.310129700083158e-09;, score=0.981 total time=   0.0s
# [CV 2/5] END var_smoothing=1.873817422860387e-09;, score=0.962 total time=   0.0s
# [CV 4/5] END var_smoothing=1.873817422860387e-09;, score=1.000 total time=   0.0s
# [CV 3/5] END var_smoothing=1.873817422860387e-09;, score=0.944 total time=   0.0s
# [CV 5/5] END var_smoothing=1.873817422860387e-09;, score=0.981 total time=   0.0s
# [CV 1/5] END var_smoothing=1.519911082952933e-09;, score=0.909 total time=   0.0s
# [CV 1/5] END var_smoothing=1.873817422860387e-09;, score=0.909 total time=   0.0s
# [CV 3/5] END var_smoothing=1.519911082952933e-09;, score=0.944 total time=   0.0s
# [CV 5/5] END var_smoothing=1.519911082952933e-09;, score=0.981 total time=   0.0s
# [CV 1/5] END var_smoothing=1.2328467394420635e-09;, score=0.909 total time=   0.0s
# [CV 4/5] END var_smoothing=1.519911082952933e-09;, score=1.000 total time=   0.0s
# [CV 2/5] END var_smoothing=1.2328467394420635e-09;, score=0.962 total time=   0.0s
# [CV 2/5] END var_smoothing=1.519911082952933e-09;, score=0.962 total time=   0.0s
# [CV 3/5] END var_smoothing=1.2328467394420635e-09;, score=0.944 total time=   0.0s
# [CV 4/5] END var_smoothing=1.2328467394420635e-09;, score=1.000 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-09;, score=0.909 total time=   0.0s
# [CV 5/5] END var_smoothing=1.2328467394420635e-09;, score=0.981 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-09;, score=0.962 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-09;, score=0.944 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-09;, score=1.000 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-09;, score=0.981 total time=   0.0s
# GridSearchCV(estimator=GaussianNB(), n_jobs=-1,
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.51119173e-02, 2.84803587e-02...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
result = grid.cv_results_
#print(result)
grid_predictions = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, grid_predictions)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)

print("\nThe confusion Matrix:\n",confusion_matrix)
print("\nThe report using GaussianNB :\n\n\n",clf_report)
# Out:
# The f1_macro value for best parameter {'var_smoothing': np.float64(0.006579332246575682)}: 0.9626932787797391
#
# The confusion Matrix:
#  [[51  0]
#  [ 5 77]]
#
# The report using GaussianNB :
#
#
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        51
#            1       1.00      0.94      0.97        82
#
#     accuracy                           0.96       133
#    macro avg       0.96      0.97      0.96       133
# weighted avg       0.97      0.96      0.96       133

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])

table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004911      0.003804         0.008167        0.005542
# 1        0.003371      0.000798         0.005030        0.001137
# 2        0.003445      0.001052         0.005042        0.000869
# 3        0.003587      0.002121         0.008884        0.008266
# 4        0.005085      0.004208         0.007830        0.005762
# ..            ...           ...              ...             ...
# 95       0.003201      0.001713         0.006268        0.003086
# 96       0.003918      0.003034         0.009231        0.004991
# 97       0.002387      0.001358         0.008573        0.005101
# 98       0.002158      0.000596         0.005656        0.002465
# 99       0.002459      0.001650         0.006622        0.002745
#
#     param_var_smoothing                                     params  \
# 0          1.000000e+00                     {'var_smoothing': 1.0}
# 1          8.111308e-01      {'var_smoothing': 0.8111308307896871}
# 2          6.579332e-01       {'var_smoothing': 0.657933224657568}
# 3          5.336699e-01       {'var_smoothing': 0.533669923120631}
# 4          4.328761e-01     {'var_smoothing': 0.43287612810830584}
# ..                  ...                                        ...
# 95         2.310130e-09   {'var_smoothing': 2.310129700083158e-09}
# 96         1.873817e-09   {'var_smoothing': 1.873817422860387e-09}
# 97         1.519911e-09   {'var_smoothing': 1.519911082952933e-09}
# 98         1.232847e-09  {'var_smoothing': 1.2328467394420635e-09}
# 99         1.000000e-09                   {'var_smoothing': 1e-09}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.740741           0.833495           0.713954
# 1            0.740741           0.833495           0.713954
# 2            0.740741           0.870619           0.754717
# 3            0.760333           0.907402           0.794081
# 4            0.779609           0.907402           0.813342
# ..                ...                ...                ...
# 95           0.908877           0.962264           0.944023
# 96           0.908877           0.962264           0.944023
# 97           0.908877           0.962264           0.944023
# 98           0.908877           0.962264           0.944023
# 99           0.908877           0.962264           0.944023
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.851225           0.907035         0.809290        0.071675
# 1            0.851225           0.907035         0.809290        0.071675
# 2            0.869925           0.907035         0.828607        0.067533
# 3            0.888515           0.925524         0.855171        0.065598
# 4            0.888515           0.944023         0.866578        0.060899
# ..                ...                ...              ...             ...
# 95           1.000000           0.981217         0.959276        0.031373
# 96           1.000000           0.981217         0.959276        0.031373
# 97           1.000000           0.981217         0.959276        0.031373
# 98           1.000000           0.981217         0.959276        0.031373
# 99           1.000000           0.981217         0.959276        0.031373
#
#     rank_test_score
# 0                99
# 1                99
# 2                98
# 3                97
# 4                96
# ..              ...
# 95                5
# 96                5
# 97                5
# 98                5
# 99                5
#
# [100 rows x 14 columns]
