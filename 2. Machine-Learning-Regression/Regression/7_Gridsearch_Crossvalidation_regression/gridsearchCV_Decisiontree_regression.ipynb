# %% [markdown]
# #gridsearchCV_Decision_Tree_regression

# %%
import pandas as pd

# %%
#load the dataset
dataset = pd.read_csv('insurance_pre.csv')

#dummy the categorical variables
dataset = pd.get_dummies(dataset, drop_first=True)
# Display the first few rows of the dataset
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
# Define the features and target variable
independent = dataset.drop('charges', axis=1)  
#print(independent)
dependent = dataset['charges']

# %%
# Import necessary libraries for model training and evaluation
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

# %%
# Initialize the DecisionTreeRegressor with GridSearchCV
# Create a GridSearchCV object with DecisionTreeRegressor
GridSearchCV = GridSearchCV(
    estimator=DecisionTreeRegressor(),
    param_grid={
        'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
        'splitter': ['best', 'random'],
        'max_features': ['auto', 'sqrt', 'log2']
    },
    refit=True,
    verbose=3,
    n_jobs=-1
)

# Fit the model using GridSearchCV
GridSearchCV.fit(independent, dependent)


# R2score value for best parameters
print(f"GridSearchCV Results R2score value for best parameters: {GridSearchCV.best_params_}")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END criterion=squared_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.766 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.599 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.715 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.723 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.706 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.619 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.632 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.687 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.475 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.681 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.754 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.694 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.628 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.706 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.720 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.678 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.539 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.700 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.659 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.675 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.704 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.656 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.669 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.574 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.561 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.719 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.677 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.583 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.730 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.631 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.799 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.633 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.738 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.564 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.744 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.720 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.639 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.653 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.696 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.689 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.703 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.648 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.629 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.696 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.773 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.530 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.574 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.688 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.719 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.622 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.749 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.693 total time=   0.0s[CV 4/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.648 total time=   0.0s
#
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.688 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.679 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.752 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=auto, splitter=random;, score=nan total time=   0.0s[CV 5/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.634 total time=   0.0s
#
# [CV 5/5] END criterion=poisson, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=auto, splitter=best;, score=nan total time=   0.0s[CV 1/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.783 total time=   0.0s
#
# [CV 5/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.721 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.734 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.567 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.684 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.659 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.693 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.490 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.759 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.707 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.670 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.687 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.655 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.677 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.716 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.716 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.486 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.704 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.763 total time=   0.0s[CV 1/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.682 total time=   0.0s
#
# [CV 3/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.609 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.620 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.645 total time=   0.0s
# GridSearchCV Results R2score value for best parameters: {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}
# /home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 39 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/deehub/JoinDeeHub/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.70186403 0.6188193  0.7004169  0.65007012
#         nan        nan 0.67665081 0.62427673 0.71727773 0.65786447
#         nan        nan 0.67897819 0.68502829 0.65582544 0.6767785
#         nan        nan 0.71212823 0.64270868 0.71067494 0.60824081]
#   warnings.warn(

# %%
# Get the results from GridSearchCV
Results = GridSearchCV.cv_results_
# Convert the results to a DataFrame for better readability
Results_df = pd.DataFrame.from_dict(Results)
Results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002379      0.000577         0.000000        0.000000
# 1        0.002229      0.000703         0.000000        0.000000
# 2        0.006696      0.000875         0.002886        0.000257
# 3        0.006928      0.001897         0.003383        0.000682
# 4        0.008572      0.002078         0.003523        0.000839
# 5        0.008026      0.002041         0.003811        0.000509
# 6        0.003480      0.001154         0.000000        0.000000
# 7        0.001681      0.000239         0.000000        0.000000
# 8        0.016514      0.005596         0.007762        0.002831
# 9        0.011289      0.002718         0.005468        0.003203
# 10       0.013299      0.004839         0.009097        0.004883
# 11       0.007759      0.002847         0.005562        0.003368
# 12       0.002204      0.001034         0.000000        0.000000
# 13       0.004161      0.002034         0.000000        0.000000
# 14       0.039378      0.013852         0.004765        0.001835
# 15       0.015298      0.002695         0.002773        0.000215
# 16       0.030388      0.009151         0.003436        0.001294
# 17       0.025946      0.008763         0.005466        0.003603
# 18       0.002860      0.001065         0.000000        0.000000
# 19       0.001929      0.001268         0.000000        0.000000
# 20       0.013218      0.001581         0.004882        0.001788
# 21       0.011447      0.006847         0.004999        0.001364
# 22       0.013076      0.004409         0.006568        0.003515
# 23       0.008282      0.002754         0.003389        0.000644
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto           best
# 1    squared_error               auto         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               auto           best
# 7     friedman_mse               auto         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               auto           best
# 13  absolute_error               auto         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               auto           best
# 19         poisson               auto         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.765761
# 3   {'criterion': 'squared_error', 'max_features':...           0.619151
# 4   {'criterion': 'squared_error', 'max_features':...           0.753931
# 5   {'criterion': 'squared_error', 'max_features':...           0.677927
# 6   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 7   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.704351
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.669458
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.799386
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.688618
# 12  {'criterion': 'absolute_error', 'max_features'...                NaN
# 13  {'criterion': 'absolute_error', 'max_features'...                NaN
# 14  {'criterion': 'absolute_error', 'max_features'...           0.647943
# 15  {'criterion': 'absolute_error', 'max_features'...           0.687831
# 16  {'criterion': 'absolute_error', 'max_features'...           0.629476
# 17  {'criterion': 'absolute_error', 'max_features'...           0.782653
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.734081
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.683916
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.716405
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.682152
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.599059           0.715180           0.723329
# 3            0.632320           0.686798           0.474695
# 4            0.694448           0.627658           0.705897
# 5            0.538911           0.700069           0.658871
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.574417           0.718690           0.729560
# 9            0.561308           0.676611           0.583303
# 10           0.632809           0.738196           0.719825
# 11           0.564333           0.744345           0.639113
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.574349           0.703264           0.696193
# 15           0.621952           0.748842           0.687850
# 16           0.530441           0.719306           0.647636
# 17           0.566636           0.706851           0.693444
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.659048           0.759265           0.687125
# 21           0.489980           0.693126           0.676912
# 22           0.654997           0.703700           0.715750
# 23           0.485741           0.608853           0.619507
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.705992         0.701864        0.055330                4
# 3            0.681132         0.618819        0.076757               15
# 4            0.720151         0.700417        0.041504                5
# 5            0.674573         0.650070        0.057114               12
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.656237         0.676651        0.056925                9
# 9            0.630704         0.624277        0.045750               14
# 10           0.696172         0.717278        0.054344                1
# 11           0.652914         0.657864        0.059244               10
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.773141         0.678978        0.065823                7
# 15           0.678667         0.685028        0.040267                6
# 16           0.752270         0.655825        0.077219               11
# 17           0.634308         0.676779        0.072563                8
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.721122         0.712128        0.035291                2
# 21           0.669609         0.642709        0.076759               13
# 22           0.762524         0.710675        0.034338                3
# 23           0.644952         0.608241        0.066248               16

# %%
age_input = int(input("Enter the age: "))
bmi_input = float(input("Enter the BMI: "))
children_input = int(input("Enter the number of children: "))
sex_male_input = int(input("Enter 1 if you are male, 0 otherwise: "))
smoker_input = int(input("Enter 1 if you are a smoker, 0 otherwise: "))

# %%
# Create a DataFrame for the input data
input_data = pd.DataFrame({
    'age': [age_input],
    'bmi': [bmi_input],
    'children': [children_input],
    'sex_male': [sex_male_input],
    'smoker_yes': [smoker_input]
})

# %%
# Make predictions using the best model
predictions = GridSearchCV.predict(input_data)
print(f"Predicted insurance charges: {predictions}")
# Out:
# Predicted insurance charges: [4151.0287]
